# %% [markdown]
# # Data Visualization
# Data visualization helps us understand the data and even extract valuable intelligence from the data. "One picture tells more than a thousand words". It is an invaluable techniques for data exploration.
#
# Data visualization is also considered business intelligence (BI). BI is about visualizing past data (what already happened) in intuitive ways using graphs and charts and helping decision making.
#
# It has become more important than ever before. It is difficult to make sense of “big data” and charts & graphs can be extremely useful for decision making.

# %% [markdown]
# ## Examples
#
# * Google Public Data Explorer ("Living longer with fewer children")
# http://www.google.com/publicdata/directory
#
# * U.S. college majors: Median yearly earnings vs. gender ratio
# http://www.randalolson.com/2015/08/16/u-s-college-majors-median-yearly-earnings-vs-gender-ratio/
# <img src = "http://www.randalolson.com/wp-content/uploads/us-college-majors-income-vs-gender-ratio-ann.png">
# <img src = "http://www.randalolson.com/wp-content/uploads/us-college-majors-income-vs-gender-ratio-regression.png">

# %% [markdown]
# ## More examples can be found from **the popular web sites**:
#
# - http://flowingdata.com/
# - http://www.visualisingdata.com/
# - http://www.informationisbeautiful.net/
# - http://www-969.ibm.com/software/analytics/manyeyes/

# %% [markdown]
# # Data Visualization using Python
# * Matplotlib package
#     * http://matplotlib.org/
#     * http://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html
# * Matplotlib package tutorials
#     * http://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html
#     * http://nbviewer.ipython.org/github/WeatherGod/AnatomyOfMatplotlib/blob/master/AnatomyOfMatplotlib-Part1-pyplot.ipynb
#     * http://pandas.pydata.org/pandas-docs/stable/visualization.html
# * Seaborn package
#     * http://stanford.edu/~mwaskom/software/seaborn/
#     * http://stanford.edu/~mwaskom/software/seaborn/examples/index.html

# %%
# !pip install Seaborn

# %%
# !pip install Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # This is a 15 minutes tutorial on data visualization (& business intelligence)
#
# We will use Python data visualization packages:
# - matplotlib
# - seaborn
#
# If your machine does not have **seaborn**, do **pip install seaborn** on command prompt (Windows) / terminal (Mac)

# %% [markdown]
# # 1. matplotlib
# - http://matplotlib.org/users/beginner.html
# - http://matplotlib.org/users/pyplot_tutorial.html
# - http://www.labri.fr/perso/nrougier/teaching/matplotlib/
# - http://pandas.pydata.org/pandas-docs/stable/visualization.html

# %%
# the popular python package for data visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# import some other packages
import numpy as np
import pandas as pd
import seaborn as sns  #package for statistical data visualization

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')

# %%
plt.plot([2, 3, 5, 1])
plt.ylabel('some numbers')

# %%
x= [1,2,3,4]
plt.plot(x)
plt.axis([0, 4, 0, 4])
plt.ylabel('some numbers')

# %%
# creat a plot by adapting the charts above
x= [1,5,6,2,3,4,4.5]
plt.plot(x)
plt.axis([0, 6, 0, 6])
plt.ylabel('some numbers')

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'g--')
#plt.axis([0, 6, 0, 20]) bo, ro
#plt.show()
#ro = red circle
#default is solid blue line

# %% [raw]
# http://jakevdp.github.io/mpl_tutorial/tutorial_pages/tut1.html
#
# Other options for the color characters are:
#  'r' = red
#  'g' = green
#  'b' = blue
#  'c' = cyan
#  'm' = magenta
#  'y' = yellow
#  'k' = black
#  'w' = white
# Options for line styles are
#  '-' = solid
#  '--' = dashed
#  ':' = dotted
#  '-.' = dot-dashed
#  '.' = points
#  'o' = filled circles
#  '^' = filled triangles

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'y--')
plt.axis([0, 6, 0, 20])
#The axis() command in the example above takes a list of [xmin, xmax, ymin, ymax] and specifies the viewport of the axes
# Out:
# [0, 6, 0, 20]

# %%
plt.plot([1,2,3,4], [1,4,9,16])
plt.axis([0, 6, 0, 20])
# Out:
# [0, 6, 0, 20]

# %%
x = [1, 2, 3, 4]
y = [1,4,9,16]
plt.plot(x, y)
plt.axis([0, 6, 0, 20])
# Out:
# [0, 6, 0, 20]

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x, y, linewidth=2.0)

# %%
plt.plot(x, y)
plt.xlabel('this is x!')
plt.ylabel('this is y!')
plt.title('My First Plot')

# %%
# creat a more complex plot by adapting the charts above (including labels)

# %%
# two separate charts
plt.figure()                  
plt.plot([1,2,3])

plt.figure() 
plt.plot([4,5,6])

# %%
# two lines in a signle chart
           
plt.plot([1,2,3])
plt.plot([4,5,6]) 
plt.plot([7,8,5])

# %%
plt.plot([1,2,3],'-b', label='sine')
plt.plot([4,5,6],'-r', label='cosine') 
plt.legend(loc='best')

# %%
# creat a plot by adapting the charts above
# two lines in a chart ... include legend

# %%
# import a new dataset (flights.xls)
# read_excel
flights = pd.read_excel("data/flights.xls")
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
# find info
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
# year          144 non-null int64
# month         144 non-null object
# passengers    144 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ KB

# %%
# using matplotlib
# histogram of passengers

plt.hist(flights['passengers'])
# Out:
# (array([ 24.,  27.,  19.,  18.,  22.,  13.,  10.,   6.,   3.,   2.]),
#  array([ 104. ,  155.8,  207.6,  259.4,  311.2,  363. ,  414.8,  466.6,
#          518.4,  570.2,  622. ]),
#  <a list of 10 Patch objects>)

# %%
# histogram with more options

plt.hist(flights['passengers'], label="passengers")
plt.xlabel('# of flight passengers')
plt.title('Flight passengers')
plt.legend()

# %%
# histogram with more options

bins = 20
plt.hist(flights['passengers'], bins, color='green', label="passengers")
plt.xlabel('# of flight passengers')
plt.title('Flight passengers')
plt.legend()

# %% [markdown]
# # 2. Seaborn: statistical data visualization
# - http://stanford.edu/~mwaskom/software/seaborn/
# - http://stanford.edu/~mwaskom/software/seaborn/tutorial/dataset_exploration.html
# <img src="images\seaborn.gif">

# %% [markdown]
# Example : The changes of flight passengers over time
# - https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.heatmap.html

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
# pivot table
flights = flights.pivot("month", "year", "passengers")
sns.heatmap(flights)

# %%
sns.heatmap(flights, annot=True, fmt="d")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(flights, annot=True, fmt="d")

#fmt is String formatting code to use when annot is True

# %% [markdown]
# The heatmap shows:
# * Air travel has steadily increased over time
# * Some busy and slow months for air travel

# %% [markdown]
# # Additional Resources

# %%
sns.heatmap(flights, linewidths=.5)

# %%
sns.heatmap(flights, cmap="YlGnBu")

# %%
sns.heatmap(flights, center=flights.loc["January", 1955])

# %% [markdown]
# ## A Tutorial: Using Seaborn To Visualize A Pandas Dataframe (Excellent)
# - http://chrisalbon.com/python/pandas_with_seaborn.html
# * Scatter plot
# * Density plot
# * Histogram
# * Box plot
# * Violin plot
# * Heatmap
# * Clustermap

# %% [markdown]
# # Brain Power
# Once you complete the tutorial, you can apply the knowledge to a new dataset (brain_size.xlsx)

# %%
df = pd.read_excel('data/brain_size.xlsx')
df.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0  Female   133  132  124     118    64.5     816932
# 1    Male   139  123  150     143    73.3    1038437
# 2    Male   133  129  128     172    68.8     965353
# 3  Female   137  132  134     147    65.0     951545
# 4  Female    99   90  110     146    69.0     928799

# %%
sns.lmplot('VIQ', 'PIQ', data=df, fit_reg=False)

# %% [markdown]
# Verbal IQ (VIQ), Performance IQ (PIQ), Full Scale IQ (FSIQ)
#
# Visualize VIQ and PIQ

# %%
sns.lmplot('VIQ', 'PIQ', data=df, fit_reg=True)

# %%
sns.kdeplot(df.VIQ)

# %%
sns.kdeplot(df.VIQ, df.PIQ)

# %%
sns.distplot(df.VIQ)

# %%
sns.boxplot([df.VIQ, df.PIQ])

# %%
sns.clustermap([df.VIQ, df.PIQ])
# Out:
# /anaconda/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
