# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://upload.wikimedia.org/wikipedia/commons/b/b9/CRISP-DM_Process_Diagram.png",width=600,height=600)
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/b9/CRISP-DM_Process_Diagram.png" width="600" height="600"/>

# %% [markdown]
# # Web scraping for Data Collection
#
# Web scraping is one popular method to collect data from the web. This method requires some knowledge of html & **xpath**.
#
# When you collect the data from websites, you need to be mindful about the website's terms and conditions. Two examples below are created for educational purpose.

# %% [markdown]
# # XPath
# - Xpath is a query language to access specific contents or data on the web page (web scraping)
# - Xpath is used to collect data from webpages

# %% [markdown]
# # XPath Tutorial
#
# - http://zvon.org/comp/r/tut-XPath_1.html#Pages~List_of_XPaths
# - http://zvon.org/xxl/XPathTutorial/General/examples.html
# - We'll learn Xpath and Web scraping by doing

# %% [markdown]
# ## This is a web page (http://sfbay.craigslist.org/search/npo)
#
# <img src="images\craiglist.gif">
#
# ## This is the html page of the above webpage
#
# <img src="images\craiglist_title.gif">

# %% [markdown]
# ## Some basic terms to know for web scraping
#
# - nodes (or elements): html tags such as div, section, span, a, p, etc.
# - attributes: more information included inside html tags, such as class, href, datetime, title, data-id, etc.
# - children: the nodes or elements in lower hierarchical levels (e.g., a is a child of span, section is a child of div)
# - parent: opposite of children

# %% [markdown]
# ## Python modules used in this lecture
#
# 1. For web scraping, you need to use a python moduel (or package) called **Request** to **access HTML file or web page** http://docs.python-requests.org/en/latest/
#
# 2. Then, **HTML and XML need to be processed** using **lxml**, a Python package http://lxml.de/
# 3. **csv** and **pandas** Python modules for **saving data in csv files**

# %% [markdown]
# # Example 1
# - http://sfbay.craigslist.org/search/npo

# %%
import requests
from lxml import html
import csv
import pandas as pd

# visit the webpage and access the web contents
r = requests.get('http://sfbay.craigslist.org/search/npo')
data = html.fromstring(r.text)

# %%
# xpath: collect the specific data you're looking for
title = data.xpath("//p[@class='result-info']/a/text()")


print title
# Out:
# ['Soccer Coordinator for Hayward SCORES--Soccer (hayward)', 'Mental Health: Full-time Care Manager, evening/weekend shifts', 'Mental Health Care Manager - Relief/On Call', '2 days fulltime with benefits, Residential Relief Manager Support/Care', 'HEALTH CARE COORDINATOR', 'Weekend job, 2nd job, Caregiver for adult with intellectual disability', 'Make a difference, Caregiver for adults with intellectual disability.', 'Sr. Administrative Assistant', 'Galileo Learning looking for year-round Tech Museum program manager!', 'Job Coach - Part Time/Substitute', 'Community Support Facilitator - Santa Clara', 'Bilingual Linkage Clinician', 'Bookkeeper (Temporary Position)', "Grant Writer - Support a nonprofit children's agency!", 'Clinical Director-Residential Treatment Center', 'Administrative Associate', "Bilingual Classroom Therapist - Children's Therapeutic Preschool", 'Clinical Training and Quality Assurance (QA) Director', 'Associate Director of Support Services', 'Property Manager (Supportive Housing)', 'Bilingual Hotline Advocate', 'Project Manager', 'Bilingual CASE MANAGER - Shelter plus Care ($21.21 hourly)', "Children's Services Associate", 'Housing Coordinator', 'Manager for Adolescent Treatment Program - ASW or MFTI Required', 'Animal and Client Care Associates - Holiday Windows - SF SPCA', 'Driver/General Maintenance', 'Part Time Janitor/Maintenance', 'Kitchen Helper', 'Family Services Director', 'Marketing Director', 'Development and Communications Associate', 'Program Coordinator / Youth Leader', 'Health Promoter III/ Patient Navigator', 'Youth Service Coordinator Job#HWAC0922172', 'Volunteer Program Manager', 'Intake Coordinator (Youth) Job# HWAC0922171', 'Food Drive & Volunteer Coordinator', 'Integrated Services Manager', 'Garden Educator - Ecology- Gardening - Multi-Arts-Literacy-Nutrition', 'Case Manager (FSP/Solano)', 'Licensed Vocational Nurse, Fairfield', 'Registered Nurse, Solano County', 'CIF Sub/ Direct Support Staff Sub', '*Clinical Supervisor/MFT or LSW for Residential Treatment Program*', 'INDEPENDENT LIVING SKILLS INSTRUCTOR', 'Administrative Assistant needed in Concord Adult Day Program', 'ADULT DAY PROGRAM -COMMUNITY TRAINING INSTRUCTOR', 'Transportation Coordinator Needed!', 'Membership Manager', 'Climate Action Now! Sidewalk Garden Program Associate', 'TAY Services Case manager', 'Resident Services Team Lead- RAD - $47,840 - $53,095', 'ASSET MANAGER - $66,381 - $73,673', 'Work for Amnesty International- Help Protect Human Rights! (Oakland)', 'Relief (On-Call) Veterinarian - Guide Dogs for the Blind', 'Program Assistant - ABA Therapy', 'Individual Giving Officer', 'Relief Registered Veterinary Technician - Guide Dogs for the Blind', 'Personal Caregiver- Flexible Hours!', 'Field Operations Scheduler', 'CHILD CARE SOLUTIONS - Mental Health Consultant', 'Make a Difference - Career Opportunity -  Paid Training - ABA Therapy', 'Make a Difference - Career Opportunity -  Paid Training - ABA Therapy', 'Make a Difference - Career Opportunity -  Paid Training - ABA Therapy', 'Make a Difference - Career Opportunity -  Paid Training - ABA Therapy', 'Serve Adults with Developmental Disabilities- Make a Difference!', 'Serve Adults with Developmental Disabilities- Make a Difference!', 'Serve Adults with Developmental Disabilities- Make a Difference!', 'Research and Analytics Manager', 'Work for Amnesty International- Help Protect Human Rights! (Oakland)', 'Work for Amnesty International-Help Protect Human Rights! (San Jose)', 'Counselor - Parker Hill Place', 'Counselor Harstad House', 'Counselor - Progress Foundation', 'Per Diem Clinical Counselor', 'Assistant Director - Progress Foundation La Posada', 'Program Clerk - Dore Residence/ Dore Clinic (30 hours full benefits)', 'Assistant Director -- Shrader House', 'Counselor - Crisis and Seniors Program', 'Licensed Vocational Nurse/ Psychiatric Tech (day shift)', 'HELP NEEDED TO SAVE LIVES IN CONFLICT AREA! - $13-$17/hour', 'Relief Counselor - Progress Foundation (Santa R ...

# %%
#xpath: collect the url information
web_url = data.xpath("//p/a/@href")
web_url
# Out:
# ['https://sfbay.craigslist.org/eby/npo/d/soccer-coordinator-for/6319462765.html',
#  'https://sfbay.craigslist.org/nby/npo/d/mental-health-full-time-care/6319110625.html',
#  'https://sfbay.craigslist.org/nby/npo/d/mental-health-care-manager/6319105549.html',
#  'https://sfbay.craigslist.org/nby/npo/d/2-days-fulltime-with-benefits/6319001908.html',
#  'https://sfbay.craigslist.org/nby/npo/d/health-care-coordinator/6318995526.html',
#  'https://sfbay.craigslist.org/nby/npo/d/weekend-job-2nd-job-caregiver/6318990570.html',
#  'https://sfbay.craigslist.org/nby/npo/d/make-difference-caregiver-for/6318979163.html',
#  'https://sfbay.craigslist.org/eby/npo/d/sr-administrative-assistant/6317265137.html',
#  'https://sfbay.craigslist.org/sby/npo/d/galileo-learning-looking-for/6317256378.html',
#  'https://sfbay.craigslist.org/sby/npo/d/job-coach-part-time-substitute/6317223846.html',
#  'https://sfbay.craigslist.org/sby/npo/d/community-support-facilitator/6317220415.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/bilingual-linkage-clinician/6317194395.html',
#  'https://sfbay.craigslist.org/eby/npo/d/bookkeeper-temporary-position/6317188751.html',
#  'https://sfbay.craigslist.org/eby/npo/d/grant-writer-support/6317168844.html',
#  'https://sfbay.craigslist.org/eby/npo/d/clinical-director-residential/6317165678.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/administrative-associate/6317149209.html',
#  'https://sfbay.craigslist.org/eby/npo/d/bilingual-classroom-therapist/6317148152.html',
#  'https://sfbay.craigslist.org/eby/npo/d/clinical-training-and-quality/6317134884.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/associate-director-of-support/6317133713.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/property-manager-supportive/6317131910.html',
#  'https://sfbay.craigslist.org/sby/npo/d/bilingual-hotline-advocate/6317127122.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/project-manager/6317108542.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/bilingual-case-manager/6317107861.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/childrens-services-associate/6317107602.html',
#  'https://sfbay.craigslist.org/eby/npo/d/housing-coordinator/6317104704.html',
#  'https://sfbay.craigslist.org/eby/npo/d/manager-for-adolescent/6317103330.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/animal-and-client-care/6317102044.html',
#  'https://sfbay.craigslist.org/sby/npo/d/driver-general-maintenance/6317093282.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/part-time-janitor-maintenance/6317092392.html',
#  'https://sfbay.craigslist.org/sby/npo/d/kitchen-helper/6317089979.html',
#  'https://sfbay.craigslist.org/sby/npo/d/family-services-director/6317082167.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/marketing-director/6317077669.html',
#  'https://sfbay.craigslist.org/nby/npo/d/development-and/6317070790.html',
#  'https://sfbay.craigslist.org/eby/npo/d/program-coordinator-youth/6317068978.html',
#  'https://sfbay.craigslist.org/nby/npo/d/health-promoter-iii-patient/6317065994.html',
#  'https://sfbay.craigslist.org/eby/npo/d/youth-service-coordinator/6317064563.html',
#  'https://sfbay.craigslist.org/nby/npo/d/volunteer-program-manager/6317062354.html',
#  'https://sfbay.craigslist.org/eby/npo/d/intake-coordinator-youth-job/6317059937.html',
#  'https://sfbay.craigslist.org/nby/npo/d/food-drive-volunteer/6317052532.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/integrated-services-manager/6317043047.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/garden-educator-ecology/6317017250.html',
#  'https://sfbay.craigslist.org/eby/npo/d/case-manager-fsp-solano/6317009668.html',
#  'https://sfbay.craigslist.org/eby/npo/d/licensed-vocational-nurse/6317009046.html',
#  'https://sfbay.craigslist.org/eby/npo/d/registered-nurse-solano-county/6317008516.html',
#  'https://sfbay.craigslist.org/eby/npo/d/cif-sub-direct-support-staff/6317006898.html',
#  'https://sfbay.craigslist.org/nby/npo/d/clinical-supervisor-mft-or/6316998569.html',
#  'https://sfbay.craigslist.org/pen/npo/d/independent-living-skills/6316991964.html',
#  'https://sfbay.craigslist.org/eby/npo/d/administrative-assistant/6316991875.html',
#  'https://sfbay.craigslist.org/pen/npo/d/adult-day-program-community/6316989056.html',
#  'https://sfbay.craigslist.org/eby/npo/d/transportation-coordinator/6316982885.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/membership-manager/6316914719.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/climate-action-now-sidewalk/6316906931.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/tay-services-case-manager/6316880760.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/resident-services-team-lead/6316837685.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/asset-manager/6316831443.html',
#  'https://sfbay.craigslist.org/eby/npo/d/work-for-amnesty/6316830505.html',
#  'https://sfbay.craigslist.org/nby/npo/d/relief-on-call-veterinarian/6316822861.html',
#  'https://sfbay.craigslist.org/eby/npo/d/program-assistant-aba-therapy/6316817821.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/individual-giving-officer/6316815809.html',
#  'https://sfbay.craigslist.org/nby/npo/d/relief-registered-veterinary/6316810391.html',
#  'https://sfbay.craigslist.org/nby/npo/d/personal-caregiver-flexible/6316807948.html',
#  'https://sfbay.craigslist.org/eby/npo/d/field-operations-scheduler/6316807807.html',
#  'https://sfbay.craigslist.org/eby/npo/d/child-care-solutions-mental/6316762922.html',
#  'https://sfbay.craigslist.org/pen/npo/d/make-difference-career/6316746556.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/make-difference-career/6316744853.html',
#  'https://sfbay.craigslist.org/pen/npo/d/make-difference-career/6316742982.html',
#  'https://sfbay.craigslist.org/pen/npo/d/make-difference-career/6316742218.html',
#  'https://sfbay.craigslist.org/nby/npo/d/serve-adults-with/6316731272.html',
#  'https://sfbay.craigslist.org/nby/npo/d/serve-adults-with/6316728581.html',
#  'https://sfbay.craigslist.org/nby/npo/d/serve-adults-with/6316723536.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/research-and-analytics-manager/6316721639.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/work-for-amnesty/6316716298.html',
#  'https://sfbay.craigslist.org/sby/npo/d/work-for-amnesty/6316712755.html',
#  'https://sfbay.craigslist.org/nby/npo/d/counselor-parker-hill-place/6316701812.html',
#  'https://sfbay.craigslist.org/nby/npo/d/counselor-harstad-house/6316699871.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/counselor-progress-foundation/6316696277.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/per-diem-clinical-counselor/6316693692.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/assistant-director-progress/6316685601.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/program-clerk-dore-residence/6316683600.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/assistant-director-shrader/6316681896.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/counselor-crisis-and-seniors/6316678852.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/licensed-vocational-nurse/6316676110.html',
#  'https://sfbay.craigslist.org/eby/npo/d/help-needed-to-save-lives-in/6316671416.html',
#  'https://sfbay.craigslist.org/nby/npo/d/relief-counselor-progress/6316668480.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/seeking-clinical-supervisor/6316661143.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/relief-counselor-progress/6316660697.html',
#  'https://sfbay.craigslist.org/nby/npo/d/relief-counselor-progress/6316658704.html',
#  'https://sfbay.craigslist.org/pen/npo/d/middle-school-chemistry/6316640873.html',
#  'https://sfbay.craigslist.org/pen/npo/d/part-time-middle-school/6316636598.html',
#  'https://sfbay.craigslist.org/eby/npo/d/wanted-now-experienced/6316630857.html',
#  'https://sfbay.craigslist.org/eby/npo/d/kids-brazilian-jiu-jitsu/6316626713.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/onejustice-staff-attorney-for/6316609110.html',
#  'https://sfbay.craigslist.org/nby/npo/d/compassionate-caregivers/6316606125.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/onejustice-senior-staff/6316599145.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/case-manager-supervisor/6316582866.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/aod-counselor-fotep-ti/6316578059.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/weekend-coordinator-fotep/6316576741.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/supervising-counselor-fotep-ti/6316575542.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/overnight-monitor-temporary/6316574583.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/child-care-assistant/6316573592.html',
#  'https://sfbay.craigslist.org/eby/npo/d/adoption-foster-care-social/6316572375.html',
#  'https://sfbay.craigslist.org/pen/npo/d/upper-school-assistant-cross/6316535014.html',
#  'https://sfbay.craigslist.org/eby/npo/d/program-supervisor-ii/6316511137.html',
#  'https://sfbay.craigslist.org/sby/npo/d/work-with-greenpeace-hourly/6316443688.html',
#  'https://sfbay.craigslist.org/eby/npo/d/work-with-greenpeace-hourly/6316435819.html',
#  'https://sfbay.craigslist.org/nby/npo/d/associate-teachers-for/6316348671.html',
#  'https://sfbay.craigslist.org/eby/npo/d/full-time-dual-diagnosis/6315843193.html',
#  'https://sfbay.craigslist.org/eby/npo/d/accounting-supervisor/6315841491.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/join-an-educational-movement/6315834926.html',
#  'https://sfbay.craigslist.org/eby/npo/d/assistant-program-director/6315832800.html',
#  'https://sfbay.craigslist.org/eby/npo/d/case-manager-sil-program/6315828096.html',
#  'https://sfbay.craigslist.org/eby/npo/d/mental-health-clinicians-for/6315824877.html',
#  'https://sfbay.craigslist.org/nby/npo/d/program-assistant-health/6315779323.html',
#  'https://sfbay.craigslist.org/sfc/npo/d/wraparound-clinician-mental/6315769535.html',
#  'https://sfbay.craigslist.org/sby/npo/d/part-time-clinical/6315767905.html',
#  'https://sfbay.craigslist.org/sby/npo/d/bilingual-outpatient/6315766867.html',
#  'https://sfbay.craigslist.org/eby/npo/d/multisystemic-therapy/6315763941.html',
#  'https://sfbay.craigslist.org/eby/npo/d/senior-administrative/6315760753.html',
#  'https://sfbay.craigslist.org/sby/npo/d/data-quality-specialist/6315751567.html',
#  'https://sfbay.craigslist.org/sby/npo/d/quality-assurance-specialist/6315741254.html']

# %%
# combine two columns
r = zip(title, web_url)
r
# changing the data more like Excel format
r_df = pd.DataFrame(r)
r_df
r_df.to_csv('r.csv',encoding = "utf-8")
r_df
# Out:
#                                                      0  \
# 0    Soccer Coordinator for Hayward SCORES--Soccer ...
# 1    Mental Health: Full-time Care Manager, evening...
# 2          Mental Health Care Manager - Relief/On Call
# 3    2 days fulltime with benefits, Residential Rel...
# 4                              HEALTH CARE COORDINATOR
# 5    Weekend job, 2nd job, Caregiver for adult with...
# 6    Make a difference, Caregiver for adults with i...
# 7                         Sr. Administrative Assistant
# 8    Galileo Learning looking for year-round Tech M...
# 9                     Job Coach - Part Time/Substitute
# 10         Community Support Facilitator - Santa Clara
# 11                         Bilingual Linkage Clinician
# 12                     Bookkeeper (Temporary Position)
# 13   Grant Writer - Support a nonprofit children's ...
# 14      Clinical Director-Residential Treatment Center
# 15                            Administrative Associate
# 16   Bilingual Classroom Therapist - Children's The...
# 17   Clinical Training and Quality Assurance (QA) D...
# 18              Associate Director of Support Services
# 19               Property Manager (Supportive Housing)
# 20                          Bilingual Hotline Advocate
# 21                                     Project Manager
# 22   Bilingual CASE MANAGER - Shelter plus Care ($2...
# 23                       Children's Services Associate
# 24                                 Housing Coordinator
# 25   Manager for Adolescent Treatment Program - ASW...
# 26   Animal and Client Care Associates - Holiday Wi...
# 27                          Driver/General Maintenance
# 28                       Part Time Janitor/Maintenance
# 29                                      Kitchen Helper
# ..                                                 ...
# 90   Kids Brazilian Jiu Jitsu Teacher Needed in Eas...
# 91     OneJustice: Staff Attorney for Pro Bono Clinics
# 92                            Compassionate Caregivers
# 93   OneJustice: Senior Staff Attorney for Pro Bono...
# 94                             Case Manager Supervisor
# 95                              AOD Counselor-FOTEP TI
# 96                         Weekend Coordinator - FOTEP
# 97                    Supervising Counselor - FOTEP TI
# 98            Overnight Monitor (Temporary) - FOTEP TI
# 99                                Child Care Assistant
# 100  Adoption/Foster Care Social Worker for Triad F...
# 101  Upper School Assistant Cross-Country &Track & ...
# 102                              Program Supervisor II
# 103        **WORK WITH GREENPEACE** Hourly and bonuses
# 104        **WORK WITH GREENPEACE** Hourly and bonuses
# 105  ASSOCIATE TEACHERS for Preschool/Child Develop...
# 106     Full-Time Dual Diagnosis Residential Counselor
# 107                              Accounting Supervisor
# 108  Join an Educational Movement! Be a Summer Prog...
# 109                         Assistant Program Director
# 110                         Case Manager - SIL Program
# 111  Mental Health Clinicians for Outpatient Progra...
# 112  Program Assistant/Health Information Specialis...
# 113  Wraparound Clinician: Mental Health Support fo...
# 114         Part-Time Clinical Intervention Specialist
# 115  Bilingual Outpatient Therapist - Support youth...
# 116  Multisystemic Therapy Clinician - Support Prob...
# 117                    Senior Administrative Assistant
# 118                            Data Quality Specialist
# 119            Quality Assurance Specialist (2017-132)
#
#                                                      1
# 0    https://sfbay.craigslist.org/eby/npo/d/soccer-...
# 1    https://sfbay.craigslist.org/nby/npo/d/mental-...
# 2    https://sfbay.craigslist.org/nby/npo/d/mental-...
# 3    https://sfbay.craigslist.org/nby/npo/d/2-days-...
# 4    https://sfbay.craigslist.org/nby/npo/d/health-...
# 5    https://sfbay.craigslist.org/nby/npo/d/weekend...
# 6    https://sfbay.craigslist.org/nby/npo/d/make-di...
# 7    https://sfbay.craigslist.org/eby/npo/d/sr-admi...
# 8    https://sfbay.craigslist.org/sby/npo/d/galileo...
# 9    https://sfbay.craigslist.org/sby/npo/d/job-coa...
# 10   https://sfbay.craigslist.org/sby/npo/d/communi...
# 11   https://sfbay.craigslist.org/sfc/npo/d/bilingu...
# 12   https://sfbay.craigslist.org/eby/npo/d/bookkee...
# 13   https://sfbay.craigslist.org/eby/npo/d/grant-w...
# 14   https://sfbay.craigslist.org/eby/npo/d/clinica...
# 15   https://sfbay.craigslist.org/sfc/npo/d/adminis...
# 16   https://sfbay.craigslist.org/eby/npo/d/bilingu...
# 17   https://sfbay.craigslist.org/eby/npo/d/clinica...
# 18   https://sfbay.craigslist.org/sfc/npo/d/associa...
# 19   https://sfbay.craigslist.org/sfc/npo/d/propert...
# 20   https://sfbay.craigslist.org/sby/npo/d/bilingu...
# 21   https://sfbay.craigslist.org/sfc/npo/d/project...
# 22   https://sfbay.craigslist.org/sfc/npo/d/bilingu...
# 23   https://sfbay.craigslist.org/sfc/npo/d/childre...
# 24   https://sfbay.craigslist.org/eby/npo/d/housing...
# 25   https://sfbay.craigslist.org/eby/npo/d/manager...
# 26   https://sfbay.craigslist.org/sfc/npo/d/animal-...
# 27   https://sfbay.craigslist.org/sby/npo/d/driver-...
# 28   https://sfbay.craigslist.org/sfc/npo/d/part-ti...
# 29   https://sfbay.craigslist.org/sby/npo/d/kitchen...
# ..                                                 ...
# 90   https://sfbay.craigslist.org/eby/npo/d/kids-br...
# 91   https://sfbay.craigslist.org/sfc/npo/d/onejust...
# 92   https://sfbay.craigslist.org/nby/npo/d/compass...
# 93   https://sfbay.craigslist.org/sfc/npo/d/onejust...
# 94   https://sfbay.craigslist.org/sfc/npo/d/case-ma...
# 95   https://sfbay.craigslist.org/sfc/npo/d/aod-cou...
# 96   https://sfbay.craigslist.org/sfc/npo/d/weekend...
# 97   https://sfbay.craigslist.org/sfc/npo/d/supervi...
# 98   https://sfbay.craigslist.org/sfc/npo/d/overnig...
# 99   https://sfbay.craigslist.org/sfc/npo/d/child-c...
# 100  https://sfbay.craigslist.org/eby/npo/d/adoptio...
# 101  https://sfbay.craigslist.org/pen/npo/d/upper-s...
# 102  https://sfbay.craigslist.org/eby/npo/d/program...
# 103  https://sfbay.craigslist.org/sby/npo/d/work-wi...
# 104  https://sfbay.craigslist.org/eby/npo/d/work-wi...
# 105  https://sfbay.craigslist.org/nby/npo/d/associa...
# 106  https://sfbay.craigslist.org/eby/npo/d/full-ti...
# 107  https://sfbay.craigslist.org/eby/npo/d/account...
# 108  https://sfbay.craigslist.org/sfc/npo/d/join-an...
# 109  https://sfbay.craigslist.org/eby/npo/d/assista...
# 110  https://sfbay.craigslist.org/eby/npo/d/case-ma...
# 111  https://sfbay.craigslist.org/eby/npo/d/mental-...
# 112  https://sfbay.craigslist.org/nby/npo/d/program...
# 113  https://sfbay.craigslist.org/sfc/npo/d/wraparo...
# 114  https://sfbay.craigslist.org/sby/npo/d/part-ti...
# 115  https://sfbay.craigslist.org/sby/npo/d/bilingu...
# 116  https://sfbay.craigslist.org/eby/npo/d/multisy...
# 117  https://sfbay.craigslist.org/eby/npo/d/senior-...
# 118  https://sfbay.craigslist.org/sby/npo/d/data-qu...
# 119  https://sfbay.craigslist.org/sby/npo/d/quality...
#
# [120 rows x 2 columns]

# %% [markdown]
# # Example 2
#
# * http://www.pythonscraping.com/pages/warandpeace.html

# %%
import requests
from lxml import html
import csv
import pandas as pd

r = requests.get('http://www.pythonscraping.com/pages/warandpeace.html')
data = html.fromstring(r.text)
print data
# Out:
# <Element html at 0x114e28940>

# %%
#get green texts
green = data.xpath("//span[@class='green']/text()")
green
# Out:
# ['Anna\nPavlovna Scherer',
#  'Empress Marya\nFedorovna',
#  'Prince Vasili Kuragin',
#  'Anna Pavlovna',
#  'St. Petersburg',
#  'the prince',
#  'Anna Pavlovna',
#  'Anna Pavlovna',
#  'the prince',
#  'the prince',
#  'the prince',
#  'Prince Vasili',
#  'Anna Pavlovna',
#  'Anna Pavlovna',
#  'the prince',
#  'Wintzingerode',
#  'King of Prussia',
#  'le Vicomte de Mortemart',
#  'Montmorencys',
#  'Rohans',
#  'Abbe Morio',
#  'the Emperor',
#  'the prince',
#  'Prince Vasili',
#  'Dowager Empress Marya Fedorovna',
#  'the baron',
#  'Anna Pavlovna',
#  'the Empress',
#  'the Empress',
#  "Anna Pavlovna's",
#  'Her Majesty',
#  'Baron\nFunke',
#  'The prince',
#  'Anna\nPavlovna',
#  'the Empress',
#  'The prince',
#  'Anatole',
#  'the prince',
#  'The prince',
#  'Anna\nPavlovna',
#  'Anna Pavlovna']

# %% [markdown]
# Some data cleaning is needed (e.g., Anna\nPavlovna Scherer). \n means new line. We need to remove them. This is an important process (**data cleansing or transformation**) in data analytics.

# %%
# get green texts
para_green = data.xpath("//span[@class='green']/text()")
for i in para_green:
   print i.replace('\n', ' ')
# Out:
# Anna Pavlovna Scherer
# Empress Marya Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron Funke
# The prince
# Anna Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna Pavlovna
# Anna Pavlovna

# %% [markdown]
# **print** (in the above statement) does not save anything. To save the extracted data, do the following (add brakets to the for loop)

# %%
para_green = [ i.replace('\n', ' ') for i in para_green ]
para_green
# Out:
# ['Anna Pavlovna Scherer',
#  'Empress Marya Fedorovna',
#  'Prince Vasili Kuragin',
#  'Anna Pavlovna',
#  'St. Petersburg',
#  'the prince',
#  'Anna Pavlovna',
#  'Anna Pavlovna',
#  'the prince',
#  'the prince',
#  'the prince',
#  'Prince Vasili',
#  'Anna Pavlovna',
#  'Anna Pavlovna',
#  'the prince',
#  'Wintzingerode',
#  'King of Prussia',
#  'le Vicomte de Mortemart',
#  'Montmorencys',
#  'Rohans',
#  'Abbe Morio',
#  'the Emperor',
#  'the prince',
#  'Prince Vasili',
#  'Dowager Empress Marya Fedorovna',
#  'the baron',
#  'Anna Pavlovna',
#  'the Empress',
#  'the Empress',
#  "Anna Pavlovna's",
#  'Her Majesty',
#  'Baron Funke',
#  'The prince',
#  'Anna Pavlovna',
#  'the Empress',
#  'The prince',
#  'Anatole',
#  'the prince',
#  'The prince',
#  'Anna Pavlovna',
#  'Anna Pavlovna']

# %%
# get red texts
red = data.xpath("//span[@class = 'red']/text()")
red
# Out:
# ["Well, Prince, so Genoa and Lucca are now just family estates of the\nBuonapartes. But I warn you, if you don't tell me that this means war,\nif you still try to defend the infamies and horrors perpetrated by\nthat Antichrist- I really believe he is Antichrist- I will have\nnothing more to do with you and you are no longer my friend, no longer\nmy 'faithful slave,' as you call yourself! But how do you do? I see\nI have frightened you- sit down and tell me all the news.",
#  'If you have nothing better to do, Count [or Prince], and if the\nprospect of spending an evening with a poor invalid is not too\nterrible, I shall be very charmed to see you tonight between 7 and 10-\nAnnette Scherer.',
#  'Heavens! what a virulent attack!',
#  "First of all, dear friend, tell me how you are. Set your friend's\nmind at rest,",
#  'Can one be well while suffering morally? Can one be calm in times\nlike these if one has any feeling?',
#  'You are\nstaying the whole evening, I hope?',
#  "And the fete at the English ambassador's? Today is Wednesday. I\nmust put in an appearance there,",
#  'My daughter is\ncoming for me to take me there.',
#  "I thought today's fete had been canceled. I confess all these\nfestivities and fireworks are becoming wearisome.",
#  'If they had known that you wished it, the entertainment would\nhave been put off,',
#  "Don't tease! Well, and what has been decided about Novosiltsev's\ndispatch? You know everything.",
#  'What can one say about it?',
#  'What has been decided? They have decided that\nBuonaparte has burnt his boats, and I believe that we are ready to\nburn ours.',
#  "Oh, don't speak to me of Austria. Perhaps I don't understand\nthings, but Austria never has wished, and does not wish, for war.\nShe is betraying us! Russia alone must save Europe. Our gracious\nsovereign recognizes his high vocation and will be true to it. That is\nthe one thing I have faith in! Our good and wonderful sovereign has to\nperform the noblest role on earth, and he is so virtuous and noble\nthat God will not forsake him. He will fulfill his vocation and\ncrush the hydra of revolution, which has become more terrible than\never in the person of this murderer and villain! We alone must\navenge the blood of the just one.... Whom, I ask you, can we rely\non?... England with her commercial spirit will not and cannot\nunderstand the Emperor Alexander's loftiness of soul. She has\nrefused to evacuate Malta. She wanted to find, and still seeks, some\nsecret motive in our actions. What answer did Novosiltsev get? None.\nThe English have not understood and cannot understand the\nself-abnegation of our Emperor who wants nothing for himself, but only\ndesires the good of mankind. And what have they promised? Nothing! And\nwhat little they have promised they will not perform! Prussia has\nalways declared that Buonaparte is invincible, and that all Europe\nis powerless before him.... And I don't believe a word that Hardenburg\nsays, or Haugwitz either. This famous Prussian neutrality is just a\ntrap. I have faith only in God and the lofty destiny of our adored\nmonarch. He will save Europe!",
#  'I think,',
#  'that if you had been\nsent instead of our dear ',
#  ' you would have captured the\n',
#  "'s consent by assault. You are so eloquent. Will you\ngive me a cup of tea?",
#  'In a moment. A propos,',
#  'I am\nexpecting two very interesting men tonight, ',
#  ',\nwho is connected with the ',
#  ' through the ',
#  ', one of\nthe best French families. He is one of the genuine emigres, the good\nones. And also the ',
#  '. Do you know that profound thinker? He\nhas been received by ',
#  '. Had you heard?',
#  'I shall be delighted to meet them,',
#  'But tell me,',
#  'is it true that the Dowager Empress wants Baron Funke\nto be appointed first secretary at Vienna? The baron by all accounts\nis a poor creature.',
#  'Baron Funke has been recommended to the Dowager Empress by her\nsister,',
#  'Now about your family. Do you know that since your daughter came\nout everyone has been enraptured by her? They say she is amazingly\nbeautiful.',
#  'I often think,',
#  "I often think how unfairly sometimes the\njoys of life are distributed. Why has fate given you two such splendid\nchildren? I don't speak of ",
#  ", your youngest. I don't like\nhim,",
#  "Two such charming children. And really you appreciate\nthem less than anyone, and so you don't deserve to have them.",
#  "I can't help it,",
#  'Lavater would have said I\nlack the bump of paternity.',
#  "Don't joke; I mean to have a serious talk with you. Do you know I\nam dissatisfied with your younger son? Between ourselves",
#  "he was mentioned at Her\nMajesty's and you were pitied....",
#  'What would you have me do?',
#  'You know I did all\na father could for their education, and they have both turned out\nfools. Hippolyte is at least a quiet fool, but Anatole is an active\none. That is the only difference between them.',
#  'And why are children born to such men as you? If you were not a\nfather there would be nothing I could reproach you with,',
#  "I am your faithful slave and to you alone I can confess that my\nchildren are the bane of my life. It is the cross I have to bear. That\nis how I explain it to myself. It can't be helped!"]

# %%
# get red texts
for i in red:
    print i.replace('\n', ' ')
# Out:
# Well, Prince, so Genoa and Lucca are now just family estates of the Buonapartes. But I warn you, if you don't tell me that this means war, if you still try to defend the infamies and horrors perpetrated by that Antichrist- I really believe he is Antichrist- I will have nothing more to do with you and you are no longer my friend, no longer my 'faithful slave,' as you call yourself! But how do you do? I see I have frightened you- sit down and tell me all the news.
# If you have nothing better to do, Count [or Prince], and if the prospect of spending an evening with a poor invalid is not too terrible, I shall be very charmed to see you tonight between 7 and 10- Annette Scherer.
# Heavens! what a virulent attack!
# First of all, dear friend, tell me how you are. Set your friend's mind at rest,
# Can one be well while suffering morally? Can one be calm in times like these if one has any feeling?
# You are staying the whole evening, I hope?
# And the fete at the English ambassador's? Today is Wednesday. I must put in an appearance there,
# My daughter is coming for me to take me there.
# I thought today's fete had been canceled. I confess all these festivities and fireworks are becoming wearisome.
# If they had known that you wished it, the entertainment would have been put off,
# Don't tease! Well, and what has been decided about Novosiltsev's dispatch? You know everything.
# What can one say about it?
# What has been decided? They have decided that Buonaparte has burnt his boats, and I believe that we are ready to burn ours.
# Oh, don't speak to me of Austria. Perhaps I don't understand things, but Austria never has wished, and does not wish, for war. She is betraying us! Russia alone must save Europe. Our gracious sovereign recognizes his high vocation and will be true to it. That is the one thing I have faith in! Our good and wonderful sovereign has to perform the noblest role on earth, and he is so virtuous and noble that God will not forsake him. He will fulfill his vocation and crush the hydra of revolution, which has become more terrible than ever in the person of this murderer and villain! We alone must avenge the blood of the just one.... Whom, I ask you, can we rely on?... England with her commercial spirit will not and cannot understand the Emperor Alexander's loftiness of soul. She has refused to evacuate Malta. She wanted to find, and still seeks, some secret motive in our actions. What answer did Novosiltsev get? None. The English have not understood and cannot understand the self-abnegation of our Emperor who wants nothing for himself, but only desires the good of mankind. And what have they promised? Nothing! And what little they have promised they will not perform! Prussia has always declared that Buonaparte is invincible, and that all Europe is powerless before him.... And I don't believe a word that Hardenburg says, or Haugwitz either. This famous Prussian neutrality is just a trap. I have faith only in God and the lofty destiny of our adored monarch. He will save Europe!
# I think,
# that if you had been sent instead of our dear
#  you would have captured the
# 's consent by assault. You are so eloquent. Will you give me a cup of tea?
# In a moment. A propos,
# I am expecting two very interesting men tonight,
# , who is connected with the
#  through the
# , one of the best French families. He is one of the genuine emigres, the good ones. And also the
# . Do you know that profound thinker? He has been received by
# . Had you heard?
# I shall be delighted to meet them,
# But tell me,
# is it true that the Dowager Empress wants Baron Funke to be appointed first secretary at Vienna? The baron by all accounts is a poor creature.
# Baron Funke has been recommended to the Dowager Empress by her sister,
# Now about your family. Do you know that since your daughter came out everyone has been enraptured by her? They say she is amazingly beautiful.
# I often think,
# I often think how unfairly sometimes the joys of life are distributed. Why has fate given you two such splendid children? I don't speak of
# , your youngest. I don't like him,
# Two such charming children. And really you appreciate them less than anyone, and so you don't deserve to have them.
# I can't help it,
# Lavater would have said I lack the bump of paternity.
# Don't joke; I mean to have a serious talk with you. Do you know I am dissatisfied with your younger son? Between ourselves
# he was mentioned at Her Majesty's and you were pitied....
# What would you have me do?
# You know I did all a father could for their education, and they have both turned out fools. Hippolyte is at least a quiet fool, but Anatole is an active one. That is the only difference between them.
# And why are children born to such men as you? If you were not a father there would be nothing I could reproach you with,
# I am your faithful slave and to you alone I can confess that my children are the bane of my life. It is the cross I have to bear. That is how I explain it to myself. It can't be helped!

# %%
# get all texts
alltexts = data.xpath("//div/text()")
alltexts
# Out:
# ['\n"',
#  '"\n',
#  '\nIt was in July, 1805, and the speaker was the well-known ',
#  ', maid of honor and favorite of the ',
#  '. With these words she greeted ',
#  ', a man\nof high rank and importance, who was the first to arrive at her\nreception. ',
#  ' had had a cough for some days. She was, as\nshe said, suffering from la grippe; grippe being then a new word in\n',
#  ', used only by the elite.\n',
#  '\nAll her invitations without exception, written in French, and\ndelivered by a scarlet-liveried footman that morning, ran as follows:\n',
#  '\n"',
#  '"\n',
#  '\n"',
#  '" replied ',
#  ', not in the\nleast disconcerted by this reception. He had just entered, wearing\nan embroidered court uniform, knee breeches, and shoes, and had\nstars on his breast and a serene expression on his flat face. He spoke\nin that refined French in which our grandfathers not only spoke but\nthought, and with the gentle, patronizing intonation natural to a\nman of importance who had grown old in society and at court. He went\nup to ',
#  ', kissed her hand, presenting to her his bald,\nscented, and shining head, and complacently seated himself on the\nsofa.\n',
#  '\n"',
#  '" said he without altering his tone, beneath the\npoliteness and affected sympathy of which indifference and even\nirony could be discerned.\n',
#  '\n"',
#  '" said ',
#  '. "',
#  '"\n',
#  '\n"',
#  '" said ',
#  '. "',
#  '"\n',
#  '\n"',
#  '"\n',
#  '\n"',
#  '" said ',
#  ', who, like a wound-up clock, by\nforce of habit said things he did not even wish to be believed.\n',
#  '\n"',
#  '"\n',
#  '\n"',
#  '" replied ',
#  ' in a cold,\nlistless tone. "',
#  '"\n',
#  '\n',
#  ' always spoke languidly, like an actor repeating a\nstale part. ',
#  ' Scherer on the contrary, despite her forty\nyears, overflowed with animation and impulsiveness. To be an\nenthusiast had become her social vocation and, sometimes even when she\ndid not feel like it, she became enthusiastic in order not to\ndisappoint the expectations of those who knew her. The subdued smile\nwhich, though it did not suit her faded features, always played\nround her lips expressed, as in a spoiled child, a continual\nconsciousness of her charming defect, which she neither wished, nor\ncould, nor considered it necessary, to correct.\n',
#  '\nIn the midst of a conversation on political matters ',
#  '\nburst out:\n',
#  '\n"',
#  '"\n',
#  '\nShe suddenly paused, smiling at her own impetuosity.\n',
#  '\n"',
#  '" said ',
#  ' with a smile, "',
#  '"\n',
#  '\n"',
#  '" she added, becoming calm again, "',
#  '"\n',
#  '\n"',
#  '" said ',
#  '. "',
#  '"\nhe added with studied carelessness as if it had only just occurred\nto him, though the question he was about to ask was the chief motive\nof his visit, "',
#  '"\n',
#  '\n',
#  ' wished to obtain this post for his son, but others\nwere trying through the ',
#  ' to secure it\nfor ',
#  '.\n',
#  '\n',
#  ' almost closed her eyes to indicate that neither she\nnor anyone else had a right to criticize what ',
#  ' desired or\nwas pleased with.\n',
#  '\n"',
#  '" was all she said, in a dry and mournful tone.\n',
#  '\nAs she named ',
#  ', ',
#  ' face suddenly assumed an\nexpression of profound and sincere devotion and respect mingled with\nsadness, and this occurred every time she mentioned her illustrious\npatroness. She added that ',
#  ' had deigned to show ',
#  ', and again her face clouded over with sadness.\n',
#  '\n',
#  ' was silent and looked indifferent. But, with the\nwomanly and courtierlike quickness and tact habitual to her, ',
#  ' wished both to rebuke him (for daring to speak he had done of\na man recommended to ',
#  ') and at the same time to console him,\nso she said:\n',
#  '\n"',
#  '"\n',
#  '\n',
#  ' bowed to signify his respect and gratitude.\n',
#  '\n"',
#  '" she continued after a short pause, drawing nearer\nto the prince and smiling amiably at him as if to show that\npolitical and social topics were ended and the time had come for\nintimate conversation- "',
#  '" she added in a tone admitting of no rejoinder and raising her\neyebrows. "',
#  '"\n',
#  '\nAnd she smiled her ecstatic smile.\n',
#  '\n"',
#  '" said ',
#  '. "',
#  '"\n',
#  '\n"',
#  '" (and her\nface assumed its melancholy expression), "',
#  '"\n',
#  '\n',
#  ' answered nothing, but she looked at him significantly,\nawaiting a reply. He frowned.\n',
#  '\n"',
#  '" he said at last. "',
#  '" He said this smiling\nin a way more natural and animated than usual, so that the wrinkles\nround his mouth very clearly revealed something unexpectedly coarse\nand unpleasant.\n',
#  '\n"',
#  '" said ',
#  ', looking up pensively.\n',
#  '\n"',
#  '"\n',
#  '\nHe said no more, but expressed his resignation to cruel fate by a\ngesture. ',
#  ' meditated.\n']

# %% [markdown]
# ## text() vs text_content()
# - text_content() - Returns the text content of the element, **including the text content of its children**, with no markup.

# %%
# get all inside span tag
allspan = data.xpath("//span/text()")
for i in allspan:
    print i.replace('\n', ' ')
# Out:
# Well, Prince, so Genoa and Lucca are now just family estates of the Buonapartes. But I warn you, if you don't tell me that this means war, if you still try to defend the infamies and horrors perpetrated by that Antichrist- I really believe he is Antichrist- I will have nothing more to do with you and you are no longer my friend, no longer my 'faithful slave,' as you call yourself! But how do you do? I see I have frightened you- sit down and tell me all the news.
# Anna Pavlovna Scherer
# Empress Marya Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# If you have nothing better to do, Count [or Prince], and if the prospect of spending an evening with a poor invalid is not too terrible, I shall be very charmed to see you tonight between 7 and 10- Annette Scherer.
# Heavens! what a virulent attack!
# the prince
# Anna Pavlovna
# First of all, dear friend, tell me how you are. Set your friend's mind at rest,
# Can one be well while suffering morally? Can one be calm in times like these if one has any feeling?
# Anna Pavlovna
# You are staying the whole evening, I hope?
# And the fete at the English ambassador's? Today is Wednesday. I must put in an appearance there,
# the prince
# My daughter is coming for me to take me there.
# I thought today's fete had been canceled. I confess all these festivities and fireworks are becoming wearisome.
# If they had known that you wished it, the entertainment would have been put off,
# the prince
# Don't tease! Well, and what has been decided about Novosiltsev's dispatch? You know everything.
# What can one say about it?
# the prince
# What has been decided? They have decided that Buonaparte has burnt his boats, and I believe that we are ready to burn ours.
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# Oh, don't speak to me of Austria. Perhaps I don't understand things, but Austria never has wished, and does not wish, for war. She is betraying us! Russia alone must save Europe. Our gracious sovereign recognizes his high vocation and will be true to it. That is the one thing I have faith in! Our good and wonderful sovereign has to perform the noblest role on earth, and he is so virtuous and noble that God will not forsake him. He will fulfill his vocation and crush the hydra of revolution, which has become more terrible than ever in the person of this murderer and villain! We alone must avenge the blood of the just one.... Whom, I ask you, can we rely on?... England with her commercial spirit will not and cannot understand the Emperor Alexander's loftiness of soul. She has refused to evacuate Malta. She wanted to find, and still seeks, some secret motive in our actions. What answer did Novosiltsev get? None. The English have not understood and cannot understand the self-abnegation of our Emperor who wants nothing for himself, but only desires the good of mankind. And what have they promised? Nothing! And what little they have promised they will not perform! Prussia has always declared that Buonaparte is invincible, and that all Europe is powerless before him.... And I don't believe a word that Hardenburg says, or Haugwitz either. This famous Prussian neutrality is just a trap. I have faith only in God and the lofty destiny of our adored monarch. He will save Europe!
# I think,
# the prince
# that if you had been sent instead of our dear
# Wintzingerode
#  you would have captured the
# King of Prussia
# 's consent by assault. You are so eloquent. Will you give me a cup of tea?
# In a moment. A propos,
# I am expecting two very interesting men tonight,
# le Vicomte de Mortemart
# , who is connected with the
# Montmorencys
#  through the
# Rohans
# , one of the best French families. He is one of the genuine emigres, the good ones. And also the
# Abbe Morio
# . Do you know that profound thinker? He has been received by
# the Emperor
# . Had you heard?
# I shall be delighted to meet them,
# the prince
# But tell me,
# is it true that the Dowager Empress wants Baron Funke to be appointed first secretary at Vienna? The baron by all accounts is a poor creature.
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# Baron Funke has been recommended to the Dowager Empress by her sister,
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron Funke
# The prince
# Anna Pavlovna
# the Empress
# Now about your family. Do you know that since your daughter came out everyone has been enraptured by her? They say she is amazingly beautiful.
# The prince
# I often think,
# I often think how unfairly sometimes the joys of life are distributed. Why has fate given you two such splendid children? I don't speak of
# Anatole
# , your youngest. I don't like him,
# Two such charming children. And really you appreciate them less than anyone, and so you don't deserve to have them.
# I can't help it,
# the prince
# Lavater would have said I lack the bump of paternity.
# Don't joke; I mean to have a serious talk with you. Do you know I am dissatisfied with your younger son? Between ourselves
# he was mentioned at Her Majesty's and you were pitied....
# The prince
# What would you have me do?
# You know I did all a father could for their education, and they have both turned out fools. Hippolyte is at least a quiet fool, but Anatole is an active one. That is the only difference between them.
# And why are children born to such men as you? If you were not a father there would be nothing I could reproach you with,
# Anna Pavlovna
# I am your faithful slave and to you alone I can confess that my children are the bane of my life. It is the cross I have to bear. That is how I explain it to myself. It can't be helped!
# Anna Pavlovna

# %%
# get the content of 1st span
para_1 = data.xpath("//span[1]/text()")
para_1
# Out:
# ["Well, Prince, so Genoa and Lucca are now just family estates of the\nBuonapartes. But I warn you, if you don't tell me that this means war,\nif you still try to defend the infamies and horrors perpetrated by\nthat Antichrist- I really believe he is Antichrist- I will have\nnothing more to do with you and you are no longer my friend, no longer\nmy 'faithful slave,' as you call yourself! But how do you do? I see\nI have frightened you- sit down and tell me all the news.",
#  'Wintzingerode',
#  'le Vicomte de Mortemart',
#  'Anatole']

# %%
# get the content of 2nd span
para_2 = data.xpath("//span[2]/text()")
para_2
# Out:
# ['Anna\nPavlovna Scherer', 'King of Prussia', 'Montmorencys']

# %% [markdown]
# # Example 3
#
# - https://en.wikipedia.org/wiki/Kansas_State_University

# %%
import requests
from lxml import html
import csv
import pandas as pd

r = requests.get('https://en.wikipedia.org/wiki/Kansas_State_University')
data = html.fromstring(r.text)

# %%
# get main texts
maintexts = data.xpath("//p/text()")
maintexts
# Out:
# [', commonly shortened to ',
#  ' or ',
#  ', is a ',
#  ' ',
#  ' with its main ',
#  ' in ',
#  ', ',
#  ", United States. Kansas State was opened as the state's ",
#  u' in 1863 \u2013 the first public institution of higher learning in the state of Kansas.',
#  ' It had a record high enrollment of 24,766 students for the Fall 2014 semester.',
#  ' are in ',
#  ' and ',
#  '. The Kansas State University Polytechnic Campus in Salina is home to the College of Technology and Aviation. The Olathe Innovation Campus is the academic research presence within the Kansas Bioscience Park, where graduate students participate in research bioenergy, animal health, plant science and food safety and security.',
#  'The university is classified as a research university with highest research activity (R1) by the ',
#  ". Kansas State's academic offerings are administered through nine colleges, including the ",
#  ' and the ',
#  " in Salina. Graduate degrees offered include 65 master's degree programs and 45 doctoral degrees.",
#  'Kansas State University, originally named ',
#  ', was founded in Manhattan on February 16, 1863, during the ',
#  ', as a ',
#  ' under the ',
#  '.',
#  ' The school was the first land-grant college created under the Morrill Act.',
#  ' K-State is the third-oldest school in the ',
#  ' and the oldest public institution of higher learning in the state of Kansas.',
#  'The effort to establish the school began in 1861, the year that ',
#  ' was admitted to the ',
#  '. One of the new state ',
#  ' top priorities involved establishing a state university. That year, the delegation from Manhattan introduced a bill to convert ',
#  ' (a private college incorporated in Manhattan in 1858) into the state university.',
#  ' But the bill establishing the university in Manhattan was controversially ',
#  ' by Governor ',
#  ' of Lawrence, and an attempt to override the veto in the Legislature failed by two votes.',
#  ' In 1862, another bill to make Manhattan the site of the state university failed by one vote.',
#  u" Finally, upon the third attempt on February 16, 1863, the state accepted Manhattan's offer to donate the Blue Mont College building and grounds and established the state's land-grant college at the site \u2013 the institution that would become Kansas State University.",
#  'When the college opened for its first session on September 2, 1863, it became only the ',
#  ' in the United States.',
#  ' Enrollment for the first session totaled 52 students: 26 men and 26 women.',
#  ' Twelve years after opening, the university moved its main campus from the location of ',
#  ' to its present site in 1875.',
#  ' The original site is now occupied by Central National Bank of Manhattan and Founders Hill Apartments.',
#  'The early years of the institution witnessed debate over whether the college should provide a focused agricultural education or a full ',
#  ' education. During this era, the tenor of the school shifted with the tenure of college presidents. For example, President ',
#  u' (1873\u20131879) favored a limited education and President ',
#  u' (1879\u20131897) favored a classic liberal education.',
#  ' Fairchild was credited with saying, "Our college exists not so much to make men farmers as to make farmers men."',
#  'During this era, in 1873, Kansas State helped pioneer the academic teaching of ',
#  ' for women, becoming one of the first two colleges to offer the program of study.',
#  'In November 1928, the school was accredited by the Association of American Universities (AAU) as a school whose graduates were deemed capable of advanced graduate work.',
#  ' The name of the school was changed in 1931 to ',
#  '. In 1959, the Kansas legislature changed the name again to ',
#  ' to reflect a growing number of graduate programs, although as a practical and legal matter it has since been referred to as ',
#  '.',
#  ' ',
#  ' served as president of the university from 1943 to 1950, and Dr. James McCain succeeded him, serving from 1950 to 1975. Several buildings, including ',
#  ' and a student union, were added to the campus in the 1950s. The 1960s witnessed demonstrations against the ',
#  ', though fewer than at other college campuses. Enrollment was relatively high through most of the 1970s, but the university endured a downward spiral from approximately 1976 to 1986, when enrollment decreased to 17,570 and a number of faculty resigned. In 1986, ',
#  ' assumed the presidency of Kansas State University. During his tenure, enrollment and donations increased.',
#  'On June 15, 2009, ',
#  ' became the 13th president of Kansas State University.',
#  ' In March 2010 he announced his K-State 2025 plan.',
#  ' The initiative is designed to elevate K-State to a top 50 nationally recognized research university by 2025. His last day was April 22, 2016, as he was selected as ',
#  "'s next president.",
#  'In late April, 2016, Ret. General ',
#  ' began serving as the interim president of Kansas State University',
#  ' and was announced as the permanent president on November 15, 2016.',
#  "The state legislature established the state's ",
#  ' in ',
#  ' on January 13, 1863.',
#  ' A commission to establish a state university in ',
#  ' was called for later in the same legislative session, provided that town could meet certain requirements,',
#  ' and finalized later in the year.',
#  'Which is the "oldest" university perhaps depends on how the term is defined. Kansas State was founded first and began teaching college-level classes in 1863, six years before the University of Kansas. Kansas State was founded with an agricultural and scientific college (consistent with the land-grant college mandate) as well as departments for military science and literature',
#  ' but was not officially labeled a university until 1959, while KU has been labeled a "university" since its enabling legislation was enacted in November 1863.',
#  u'The main campus of Kansas State University in Manhattan now covers 668 acres (2.70\xa0km',
#  '). The campus is historic, featuring more ',
#  ' than any other campus in Kansas. Holtz Hall, built in 1876, is the oldest free-standing building on campus.',
#  ' However, the oldest building on campus is the original section of Seaton Hall, which now forms Seaton Court, facing the courtyard of ',
#  ' and Eisenhower Hall. Originally named the Industrial Workshop, this section of Seaton Hall is the oldest remaining education building on the Manhattan campus.',
#  'The predominant architectural feature of the Manhattan campus is its use of native ',
#  '. This includes the signature building at Kansas State University, ',
#  ', developed in three stages between 1877 and 1885. Anderson Hall, now listed on the ',
#  u", has housed the university's administrative offices for more than a century. Although there are many historic building on the campus, since 1986 Kansas State has also added over two million square feet (186,000\xa0m\xb2) of new buildings to the campus, including an expanded library, new art museum, and plant sciences building.",
#  'Several of the buildings on campus were heavily damaged by an EF4 ',
#  ' on ',
#  '. Damage estimates totaled more than $20 million.',
#  ' K-State paid a deductible of $5 million for their insurance to repair all damages.',
#  'Since 2014, the Main campus has been under significant renovation to accommodate infrastructure changes. The campus is also adopting a more walking friendly atmosphere by closing off many small access roads to vehicles.',
#  'Since 1986, Kansas State ranks first nationally among public universities in its total of ',
#  ', ',
#  ', ',
#  ', ',
#  ', and Udall scholars with 124 recipients.',
#  ' The school is a member of the Midwestern Association of Graduate Schools, and is home to the Kansas Beta chapter of the ',
#  ' honor society. The institution petitioned in 1925, and three years later received, a charter of ',
#  ' National College Senior Honor Society.',
#  'Kansas State University has 65 academic departments in nine colleges: ',
#  '; ',
#  ', Planning and Design; Arts and Sciences; ',
#  '; ',
#  '; ',
#  '; ',
#  '; ',
#  ' and ',
#  '; and ',
#  ". The graduate school offers 65 master's degree programs and nearly 50 doctoral programs.",
#  'In 1991, the former Kansas Technical Institute in ',
#  ' was merged with Kansas State University by an act of the ',
#  u' legislature. The College of Technology and Aviation is at the Salina campus. Initially, this campus was referred to as Kansas State University \u2013 Salina, but on October 14, 2014, the Kansas Board of Regents approved a name change to ',
#  '.',
#  'K-State implemented an academic ',
#  ' in 1999.',
#  ' When students are admitted, it is implied that they will adhere to the Honor Pledge: "On my honor, as a student, I have neither given nor received unauthorized aid on this academic work."',
#  'The university has had a long-standing interest in ',
#  ', particularly native ',
#  ' plant and animal life. The ',
#  ' is an on-campus ',
#  ' display garden that serves as an educational resource and learning laboratory for K-State students and the public. The ',
#  ' is a native tallgrass prairie preserve south of Manhattan, which is co-owned by ',
#  u' and Kansas State University and operated as a field research station by the department of biology. The university also owns an additional 18,000 acres (73\xa0km',
#  ') in cities across the state that it operates as Agricultural Experiment Stations in research centers in Hays, Garden City, Colby, and Parsons.',
#  'In 2006, K-State dedicated the Biosecurity Research Institute.',
#  ' The BRI, in Pat Roberts Hall, is a safe and secure location in which scientists and their collaborators can study high-consequence pathogens. It was designed and constructed for biosafety level 3 (BSL-3) and biosafety level 3 agriculture (BSL-3Ag) research.',
#  'The availability of the BRI was part of what attracted the ',
#  ' (NBAF) to K-State and Manhattan.',
#  u' The NBAF will feature about 500,000 square feet (46,000\xa0m',
#  ') of research and support space.',
#  ' Construction of the NBAF will cost more than $750 million and should be complete by 2016.',
#  " It will stand just north of K-State's College of Veterinary Medicine and the BRI.",
#  'Following the NBAF decision, leaders at two additional federal facilities announced they are coming to K-State. The Arthropod-Borne Animal Disease Research Unit, or ABADRU, specializes in animal and plant diseases transmitted by insects. The lab relocated from Laramie, Wyo., to K-State in order to fully realize its research mandate.',
#  " The Center of Excellence for Emerging and Zoonotic Animal Diseases, or CEEZAD, will research foreign animal, zoonotic and newly discovered pathogens that can have a consequential economic impact on U.S. agriculture, homeland security and human and animal health. It will be led by K-State's Dr. Juergen Richt.",
#  "The university's extensive list of research facilities includes the James R. Macdonald Laboratory for research in atomic, molecular and optical physics and the ",
#  ' Center for Gravitational Studies in Cellular and Developmental Biology. The ',
#  ', which made ',
#  ' eye surgery possible, is a technology developed by Kansas State researchers.',
#  'Other research facilities include:',
#  "Kansas State was involved in early experimentation with television and radio broadcasts. The first radio station licensed in Manhattan was Kansas State's experimental station 9YV.",
#  ' In 1912 the station began a daily broadcast (in ',
#  ') of the ',
#  ', becoming the first radio station in the U.S. to air a regularly-scheduled forecast.',
#  u' After a series of efforts to secure a more high-powered signal for the university \u2013 including a brief cooperation with ',
#  u"'s notorious KFKB \u2013 Kansas State was granted a license for ",
#  ', which began broadcasting with 500 watts of power on December 1, 1924.',
#  ' The station was reassigned to the frequency of AM 580 in 1928, and continued broadcasting on that frequency until November 27, 2002, when it made its last broadcast after the frequency was bought out by ',
#  ' in ',
#  '.',
#  'On March 9, 1932, the ',
#  ' granted Kansas State a license to operate the television station W9XAK.',
#  ' It was the first television station in ',
#  '.',
#  ' Activity on the station peaked in 1933 and 1934, with original programs being produced three nights a week. On October 28, 1939, the station broadcast the ',
#  ' in Manhattan between ',
#  ' and ',
#  ', which was the second college football game ever televised.',
#  ' The station went off the air in 1939.',
#  'The university is home to several museums, including the ',
#  ', the KSU Historic Costume and Textiles Museum, the K-State Insect Zoo, and the Chang, Chapman, and Kemper galleries, which feature faculty and student artwork. The university also offers an annual cycle of performance art at McCain Auditorium, including concerts, plays and dance.',
#  'K-State is also known for several distinguished lecture series: ',
#  ', Lou Douglas Lecture, Huck Boyd Lecture, and Dorothy L. Thompson Civil Rights Lectures. The ',
#  u' annually brings high-profile speakers to KSU \u2013 primarily current or former political or government leaders. Speakers in the last few years include President George W. Bush, President Bill Clinton, former Mexican President Vicente Fox and U.S. Supreme Court Justice Sonia Sotomayor. Overall, seven ',
#  ' and ten current or former foreign heads of state have given Landon Lectures at K-State since the series was inaugurated in 1966.',
#  ' The series is named after former Kansas governor and presidential candidate ',
#  '.',
#  u'The former All-University Convocation lecture series \u2013 which began with a speech by ',
#  ' on April 3, 1963, and ended in 1997',
#  u' \u2013 brought to campus prominent leaders such as ',
#  ', Supreme Court Justices ',
#  ' and ',
#  ', Senate Minority Leader ',
#  ', Rep. ',
#  ', and thinkers such as ',
#  ', Dr. ',
#  ', ',
#  ', ',
#  ', and ',
#  '.',
#  'K-State has twelve residence halls on campus: Boyd Hall, ',
#  ', ',
#  ', ',
#  ', ',
#  ', ',
#  ', ',
#  ', Putnam Hall, Van Zile Hall, and the new Wefald hall, completed in 2016.',
#  ' The Living Community at Jardine, and Smurthwaite, as well as Jardine Apartments. Smurthwaite, Ford, and Boyd Halls are all female. Haymaker and Marlatt Halls were all-male residence halls until the fall semesters of 2002 and 2009 respectively, when they became co-educational.',
#  ' The residence halls are divided into three complexes: Derby, Kramer, and Strong.',
#  'Kansas State has more than 400 student organizations.',
#  ' The Student Governing Association is the largest organization of student leaders, composed of elected and appointed officials. The Student Governing Association follows the model of the ',
#  ', with ',
#  ', ',
#  ' and ',
#  ' branches.',
#  "The Association of Residence Halls (KSUARH) is the second largest organization of student leaders working towards better the on-campus living experience for students living in the Residence Halls around campus. GSA is the Graduate Student Association, and members include K-State's graduate-level business students. GSC is the Graduate Student Council, open to graduate-level students of all disciplines. Kansas State University also offers Army ROTC (Reserve Officers' Training Corps) and Air Force ROTC programs.",
#  'Student media includes ',
#  ' The Wildcat 91.9 Student Radio, the ',
#  ', the ',
#  ', and the "Purple Power Hour," "Manhattan Matters," & "Wildcat Watch".',
#  ' is the name of the official school song of Kansas State University. In 1888, when the University was still Kansas State Agricultural College, H.W. Jones submitted the song as part of a school-wide contest. It was originally a four-stanza song and, over the years, some lyrics have changed.',
#  ' The song is sung at most K-State sporting events by fans, students and alumni. ',
#  ' and ',
#  ' are both commonly used as fight songs. Wildcat Victory is used by many high schools as their fight song.',
#  'For nearly 100 years, K-State has been home to several national and international social-leadership and service fraternities and sororities. An important and historic aspect of what they refer to as "the Wildcat family", fraternal organizations have had a tremendous influence on the campus. Several buildings were named after fraternal members, and after the multitude of contributions given in the forms of what they refer to as time, talent and treasure.',
#  "Intercollegiate sports began at Kansas State in the 1890s. The school's sports teams are called the Wildcats, and they participate in the ",
#  ' and the ',
#  '. The ',
#  ' is ',
#  ', making Kansas State one of very few schools (alongside ',
#  ' and ',
#  ') that have only one official color.',
#  ' White and silver are commonly used as complementary colors; white is mentioned with purple in the university\'s fight song "Wildcat Victory." The athletics logo is a stylized Wildcat head in profile usually featured in the school color, called the "Powercat."',
#  'Sports sponsored by the school include ',
#  ', ',
#  ', ',
#  ' and ',
#  ', ',
#  ', ',
#  ', ',
#  ', ',
#  ", women's soccer, and ",
#  '. The head football coach is ',
#  ", the head men's basketball coach is ",
#  ", the head women's basketball coach is ",
#  ', and the head baseball coach is ',
#  u". In 2012\u22122013, Kansas State became only the second Big 12 school to win conference titles in football, men's basketball, and baseball in the same school year.",
#  'Historically, ',
#  ' athletes at Kansas State were responsible for breaking the modern "color barrier" in ',
#  " athletics. Harold Robinson became the first African-American athlete in the conference in more than two decades and the first ever to receive a scholarship, playing football for Kansas State in 1949. In the spring of 1951 the conference's baseball color barrier was broken by Kansas State's ",
#  u", and in the winter of 1951\u20131952 Kansas State's Gene Wilson broke the conference color barrier in basketball (together with ",
#  ' at the ',
#  ').',
#  'Beginning with the first graduating class in 1867,',
#  ' a number of Kansas State alums have gone on to distinguished careers. The current ',
#  ' and one ',
#  ' are graduates of Kansas State University. Other graduates currently serve as the vice-president of ',
#  ', the ',
#  ' of the ',
#  ', and the ',
#  ' of the ',
#  '. Kansas State alums have been enshrined in the ',
#  ' and the ',
#  ', served as Chairman of the Joint Chiefs of Staff, and have earned ',
#  ' and ',
#  ' gold medals.',
#  "In line with its roots as a land grant college, a number of Kansas State's most eminent ",
#  ' in its earliest years were in the areas of agriculture, science and military. For example, famed geologist ',
#  ' was chair of the geology department, while famed Army officer ',
#  ', the subject of the essay ',
#  ', served as professor of military tactics.',
#  'Kansas State faculty have received a number of awards. Prof. ',
#  ' was awarded the ',
#  ' in 1929, while teaching history at Kansas State. In 2008, ',
#  ' and the ',
#  ' honored ',
#  ' as national Professor of the Year. At least eight Kansas State faculty members have gone on to serve as university presidents, including ',
#  ', the first Hispanic female president of an American public university.']

# %%
# get main texts
maintexts = data.xpath("//p/text()")
for i in maintexts:
    maintexts_df = i.replace('\n', ' ')
maintexts_df
# Out:
# ', the first Hispanic female president of an American public university.'

# %%
# get the list of Fraternities
fra = data.xpath("//td[1]/ul/li/a/text()")
fra
# Out:
# ['Acacia',
#  'Alpha Gamma Rho',
#  'Alpha Kappa Lambda',
#  'Alpha Phi Alpha',
#  'Alpha Phi Omega',
#  'Alpha Tau Omega',
#  'Alpha Chi Sigma',
#  'Beta Sigma Psi',
#  'Beta Theta Pi',
#  'Delta Chi',
#  'Delta Lambda Phi',
#  'Delta Sigma Phi',
#  'Delta Upsilon',
#  'FarmHouse',
#  'Iota Phi Theta',
#  'Kappa Alpha Psi',
#  'Kappa Sigma',
#  'Lambda Chi Alpha',
#  'Omega Psi Phi',
#  'Phi Beta Sigma',
#  'Phi Delta Theta',
#  'Phi Gamma Delta',
#  'Phi Kappa Theta',
#  'Pi Kappa Alpha',
#  'Pi Kappa Phi',
#  'Sigma Alpha Epsilon',
#  'Sigma Chi',
#  'Sigma Lambda Beta',
#  'Sigma Nu',
#  'Sigma Phi Epsilon',
#  'Sigma Pi',
#  'Tau Kappa Epsilon',
#  'Theta Xi',
#  'Triangle']

# %%
# get the list of Fraternities URLs
fra_url= data.xpath("//td[1]/ul/li/a/@href")
fra_url
# Out:
# ['/wiki/Acacia_Fraternity',
#  '/wiki/Alpha_Gamma_Rho',
#  '/wiki/Alpha_Kappa_Lambda',
#  '/wiki/Alpha_Phi_Alpha',
#  '/wiki/Alpha_Phi_Omega',
#  '/wiki/Alpha_Tau_Omega',
#  '/wiki/Alpha_Chi_Sigma',
#  '/wiki/Beta_Sigma_Psi',
#  '/wiki/Beta_Theta_Pi',
#  '/wiki/Delta_Chi',
#  '/wiki/Delta_Lambda_Phi',
#  '/wiki/Delta_Sigma_Phi',
#  '/wiki/Delta_Upsilon',
#  '/wiki/FarmHouse',
#  '/wiki/Iota_Phi_Theta',
#  '/wiki/Kappa_Alpha_Psi',
#  '/wiki/Kappa_Sigma',
#  '/wiki/Lambda_Chi_Alpha',
#  '/wiki/Omega_Psi_Phi',
#  '/wiki/Phi_Beta_Sigma',
#  '/wiki/Phi_Delta_Theta',
#  '/wiki/Phi_Gamma_Delta',
#  '/wiki/Phi_Kappa_Theta',
#  '/wiki/Pi_Kappa_Alpha',
#  '/wiki/Pi_Kappa_Phi',
#  '/wiki/Sigma_Alpha_Epsilon',
#  '/wiki/Sigma_Chi',
#  '/wiki/Sigma_Lambda_Beta',
#  '/wiki/Sigma_Nu',
#  '/wiki/Sigma_Phi_Epsilon',
#  '/wiki/Sigma_Pi',
#  '/wiki/Tau_Kappa_Epsilon',
#  '/wiki/Theta_Xi',
#  '/wiki/Triangle_Fraternity']

# %%
import csv
import pandas as pd

fra = data.xpath("//td[1]/ul/li/a/text()")
fra_url= data.xpath("//td[1]/ul/li/a/@href")

#combining two columns
fra_data = zip(fra, fra_url)
#chaning the data format to excel-like
fra_data = pd.DataFrame(fra_data)
#finally saving the data
fra_data.to_csv("data/output_fradata.csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-23-c7763e1901aa> in <module>()
#      10 fra_data = pd.DataFrame(fra_data)
#      11 #finally saving the data
# ---> 12 fra_data.to_csv("data/output_fradata.csv")
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# /anaconda/lib/python2.7/site-packages/pandas/io/formats/format.pyc in save(self)
#    1575             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1576                                      encoding=self.encoding,
# -> 1577                                      compression=self.compression)
#    1578             close = True
#    1579
#
# /anaconda/lib/python2.7/site-packages/pandas/io/common.pyc in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     377         if compat.PY2:
#     378             # Python 2
# --> 379             f = open(path_or_buf, mode)
#     380         elif encoding:
#     381             # Python 3 and encoding
#
# IOError: [Errno 2] No such file or directory: 'data/output_fradata.csv'

# %%
# get the sororities list, their urls

sor = data.xpath("//td[2]/ul/li/a/text()")
sor_url = data.xpath("//td[2]/ul/li/a/@href")

sor_data = zip(sor, sor_url)
sor_data_df = pd.DataFrame(sor_data)
print sor_data_df
# Out:
#                      0                                                  1
# 0      Alpha Chi Omega                              /wiki/Alpha_Chi_Omega
# 1       Alpha Delta Pi                               /wiki/Alpha_Delta_Pi
# 2    Alpha Gamma Delta                            /wiki/Alpha_Gamma_Delta
# 3    Alpha Kappa Alpha                            /wiki/Alpha_Kappa_Alpha
# 4       Alpha Xi Delta                               /wiki/Alpha_Xi_Delta
# 5       Beta Sigma Chi  /w/index.php?title=Beta_Sigma_Chi&action=edit&...
# 6            Chi Omega                                    /wiki/Chi_Omega
# 7    Delta Delta Delta                            /wiki/Delta_Delta_Delta
# 8    Delta Sigma Theta                            /wiki/Delta_Sigma_Theta
# 9       Gamma Phi Beta                               /wiki/Gamma_Phi_Beta
# 10    Gamma Rho Lambda                             /wiki/Gamma_Rho_Lambda
# 11   Kappa Alpha Theta                            /wiki/Kappa_Alpha_Theta
# 12         Kappa Delta                                  /wiki/Kappa_Delta
# 13   Kappa Kappa Gamma                            /wiki/Kappa_Kappa_Gamma
# 14     Lambda Theta Nu                              /wiki/Lambda_Theta_Nu
# 15         Pi Beta Phi                                  /wiki/Pi_Beta_Phi
# 16         Sigma Kappa                                  /wiki/Sigma_Kappa
# 17  Sigma Lambda Gamma                           /wiki/Sigma_Lambda_Gamma
# 18     Sigma Gamma Rho                              /wiki/Sigma_Gamma_Rho
# 19       Zeta Phi Beta                                /wiki/Zeta_Phi_Beta
# 20      Zeta Tau Alpha                               /wiki/Zeta_Tau_Alpha

# %%
# save the data
sor = data.xpath("//td[2]/ul/li/a/text()")
sor_url = data.xpath("//td[2]/ul/li/a/@href")

sor_data = zip(sor, sor_url)
sor_data_df = pd.DataFrame(sor_data)
sor_data_df.to_csv("data/output_sordata.csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-25-95abaff1e308> in <module>()
#       5 sor_data = zip(sor, sor_url)
#       6 sor_data_df = pd.DataFrame(sor_data)
# ----> 7 sor_data_df.to_csv("data/output_sordata.csv")
#       8
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# /anaconda/lib/python2.7/site-packages/pandas/io/formats/format.pyc in save(self)
#    1575             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1576                                      encoding=self.encoding,
# -> 1577                                      compression=self.compression)
#    1578             close = True
#    1579
#
# /anaconda/lib/python2.7/site-packages/pandas/io/common.pyc in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     377         if compat.PY2:
#     378             # Python 2
# --> 379             f = open(path_or_buf, mode)
#     380         elif encoding:
#     381             # Python 3 and encoding
#
# IOError: [Errno 2] No such file or directory: 'data/output_sordata.csv'

# %% [markdown]
# # Example 4
#
# - http://econpy.pythonanywhere.com/ex/001.html

# %%
# visit the webpage and access the web contents
r = requests.get('http://econpy.pythonanywhere.com/ex/001.html')
data = html.fromstring(r.text)

# %%
#create a list of buyers:
b = data.xpath("//div[@title = 'buyer-name']/text()")


#create a list of prices
p = data.xpath("//span[@class = 'item-price']/text()")



# combine two columns
buyer_info = zip(b,p)
buyer_info

# changing the data more like Excel format
buyer_info_df = pd.DataFrame(buyer_info)
buyer_info_df
# Out:
#                          0        1
# 0            Carson Busses   $29.95
# 1             Earl E. Byrd    $8.37
# 2              Patty Cakes   $15.26
# 3   Derri Anne Connecticut   $19.25
# 4                 Moe Dess   $19.25
# 5           Leda Doggslife   $13.99
# 6                Dan Druff   $31.57
# 7                Al Fresco    $8.49
# 8                  Ido Hoe   $14.47
# 9             Howie Kisses   $15.86
# 10               Len Lease   $11.11
# 11               Phil Meup   $15.98
# 12                Ira Pent   $16.27
# 13            Ben D. Rules    $7.50
# 14             Ave Sectomy   $50.85
# 15           Gary Shattire   $14.26
# 16              Bobbi Soks    $5.68
# 17            Sheila Takya   $15.00
# 18             Rose Tattoo  $114.07
# 19                Moe Tell   $10.09

# %% [markdown]
# ### Simple data analysis

# %%
# view the first five row
buyer_info_df.head()
buyer_info_df.tail()
buyer_info_df.iloc[[2]]
buyer_info_df.iloc[2:5]
# Out:
#                         0       1
# 2             Patty Cakes  $15.26
# 3  Derri Anne Connecticut  $19.25
# 4                Moe Dess  $19.25

# %%
#find out the dataset
buyer_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
# 0    20 non-null object
# 1    20 non-null object
# dtypes: object(2)
# memory usage: 392.0+ bytes

# %% [markdown]
# #### Data types in Python
#
# There are different **data types**:
#
# 1. object : string (e.g., last name, non-numeric values)
# 2. int : integer values
# 3. float : decimal values

# %%
#remove dollar sign
buyer_info_df[1] = buyer_info_df[1].str.replace('$', '')
buyer_info_df.head()
# Out:
#                         0      1
# 0           Carson Busses  29.95
# 1            Earl E. Byrd   8.37
# 2             Patty Cakes  15.26
# 3  Derri Anne Connecticut  19.25
# 4                Moe Dess  19.25

# %%
buyer_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
# 0    20 non-null object
# 1    20 non-null object
# dtypes: object(2)
# memory usage: 392.0+ bytes

# %%
#convert object to number
buyer_info_df[1] = pd.to_numeric(buyer_info_df[1])
buyer_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
# 0    20 non-null object
# 1    20 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 392.0+ bytes

# %% [markdown]
# 0 and 1 are the default column names. You can change the column names.

# %%
df=buyer_info_df.rename(columns={0: 'Buyers', 1: 'Prices'})
df.head()
# Out:
#                    Buyers  Prices
# 0           Carson Busses   29.95
# 1            Earl E. Byrd    8.37
# 2             Patty Cakes   15.26
# 3  Derri Anne Connecticut   19.25
# 4                Moe Dess   19.25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
# Buyers    20 non-null object
# Prices    20 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 392.0+ bytes

# %%
# summary statistics
df.describe()
# Out:
#            Prices
# count   20.000000
# mean    21.863500
# std     24.024161
# min      5.680000
# 25%     10.855000
# 50%     15.130000
# 75%     19.250000
# max    114.070000

# %%
# simple descriptive statistics
df['Tax_Amounts'] = df['Prices'] * 0.0825
df.head()
# Out:
#                    Buyers  Prices  Tax_Amounts
# 0           Carson Busses   29.95     2.470875
# 1            Earl E. Byrd    8.37     0.690525
# 2             Patty Cakes   15.26     1.258950
# 3  Derri Anne Connecticut   19.25     1.588125
# 4                Moe Dess   19.25     1.588125

# %%
df['Totals'] = df['Prices'] + df['Tax_Amounts']
df.head()
# Out:
#                    Buyers  Prices  Tax_Amounts     Totals
# 0           Carson Busses   29.95     2.470875  32.420875
# 1            Earl E. Byrd    8.37     0.690525   9.060525
# 2             Patty Cakes   15.26     1.258950  16.518950
# 3  Derri Anne Connecticut   19.25     1.588125  20.838125
# 4                Moe Dess   19.25     1.588125  20.838125

# %%
df.describe()
# Out:
#            Prices  Tax_Amounts      Totals
# count   20.000000    20.000000   20.000000
# mean    21.863500     1.803739   23.667239
# std     24.024161     1.981993   26.006154
# min      5.680000     0.468600    6.148600
# 25%     10.855000     0.895538   11.750538
# 50%     15.130000     1.248225   16.378225
# 75%     19.250000     1.588125   20.838125
# max    114.070000     9.410775  123.480775

# %%
# who paid most?
df.sort_values('Prices', ascending=False)
# another way
top = df.sort_values('Prices', ascending=False)
top.head()
# Out:
#                     Buyers  Prices  Tax_Amounts      Totals
# 18             Rose Tattoo  114.07     9.410775  123.480775
# 14             Ave Sectomy   50.85     4.195125   55.045125
# 6                Dan Druff   31.57     2.604525   34.174525
# 0            Carson Busses   29.95     2.470875   32.420875
# 3   Derri Anne Connecticut   19.25     1.588125   20.838125

# %%
# who paid least?
df.sort_values('Prices', ascending=True)
# Out:
#                     Buyers  Prices  Tax_Amounts      Totals
# 16              Bobbi Soks    5.68     0.468600    6.148600
# 13            Ben D. Rules    7.50     0.618750    8.118750
# 1             Earl E. Byrd    8.37     0.690525    9.060525
# 7                Al Fresco    8.49     0.700425    9.190425
# 19                Moe Tell   10.09     0.832425   10.922425
# 10               Len Lease   11.11     0.916575   12.026575
# 5           Leda Doggslife   13.99     1.154175   15.144175
# 15           Gary Shattire   14.26     1.176450   15.436450
# 8                  Ido Hoe   14.47     1.193775   15.663775
# 17            Sheila Takya   15.00     1.237500   16.237500
# 2              Patty Cakes   15.26     1.258950   16.518950
# 9             Howie Kisses   15.86     1.308450   17.168450
# 11               Phil Meup   15.98     1.318350   17.298350
# 12                Ira Pent   16.27     1.342275   17.612275
# 4                 Moe Dess   19.25     1.588125   20.838125
# 3   Derri Anne Connecticut   19.25     1.588125   20.838125
# 0            Carson Busses   29.95     2.470875   32.420875
# 6                Dan Druff   31.57     2.604525   34.174525
# 14             Ave Sectomy   50.85     4.195125   55.045125
# 18             Rose Tattoo  114.07     9.410775  123.480775

# %% [markdown]
# # Example 5
# - https://en.wikipedia.org/wiki/List_of_current_NBA_team_rosters

# %%
r = requests.get('https://en.wikipedia.org/wiki/List_of_current_NBA_team_rosters')
data = html.fromstring(r.text)

# %%
# get names
name = data.xpath('//tr/td[3]/a/text()')
# get schools (or from)
school = data.xpath('//tr/td[7]/a/text()')

finaldata = zip(name, school)
finaldata
# Out:
# [('Allen, Kadeem', 'Arizona'),
#  ('Baynes, Aron', 'Washington State'),
#  ('Bird, Jabari', 'UC Berkeley'),
#  ('Brown, Jaylen', 'UC Berkeley'),
#  ('Hayward, Gordon', 'Butler'),
#  ('Horford, Al', 'Florida'),
#  ('Irving, Kyrie', 'Duke'),
#  ('Larkin, Shane', 'Miami (FL)'),
#  ('Morris, Marcus', 'Kansas'),
#  ('Nader, Abdel', 'Iowa State'),
#  ('Ojeleye, Semi', 'Southern Methodist'),
#  ('Rozier, Terry', 'Louisville'),
#  ('Smart, Marcus', 'Oklahoma State'),
#  ('Tatum, Jayson', 'Duke'),
#  ('Theis, Daniel', 'Germany'),
#  ('Yabusele, Guerschon', 'France'),
#  ('Acy, Quincy', 'Baylor'),
#  ('Allen, Jarrett', 'Texas'),
#  ('Booker, Trevor', 'Clemson'),
#  ('Carroll, DeMarre', 'Missouri'),
#  ('Crabbe, Allen', 'UC Berkeley'),
#  ('Dinwiddie, Spencer', 'Colorado'),
#  ('Doyle, Milton', 'Loyola (IL)'),
#  ('Harris, Joe', 'Virginia'),
#  ('Hollis-Jefferson, Rondae', 'Arizona'),
#  ('Kilpatrick, Sean', 'Cincinnati'),
#  ('LeVert, Caris', 'Michigan'),
#  ('Lin, Jeremy', 'Harvard'),
#  ('Mozgov, Timofey', 'Russia'),
#  ('Ouattara, Yakuba', 'Ghana'),
#  ('Senglin, Jeremy', 'Weber State'),
#  ("Russell, D'Angelo", 'Ohio State'),
#  ('Whitehead, Isaiah', 'Seton Hall'),
#  ('Wiley, Jacob', 'Eastern Washington'),
#  ('Anthony, Carmelo', 'Syracuse'),
#  ('Artis, Jamel', 'Pittsburgh'),
#  ('Baker, Ron', 'Wichita State'),
#  ('Beasley, Michael', 'Kansas State'),
#  ('Dotson, Damyean', 'Houston'),
#  ('Hardaway, Tim', 'Michigan'),
#  ('Hayes, Nigel', 'Wisconsin'),
#  (u'Hernang\xf3mez, Willy', 'Spain'),
#  ('Jaramaz, Ognjen', 'Serbia'),
#  ('Kornet, Luke', 'Vanderbilt'),
#  ('Kuzminskas, Mindaugas', 'Lithuania'),
#  ('Lee, Courtney', 'Western Kentucky'),
#  ('Noah, Joakim', 'Florida'),
#  ('Ntilikina, Frank', 'France'),
#  ("O'Quinn, Kyle", 'Norfolk State'),
#  (u'Porzi\u0146\u0123is, Kristaps', 'Latvia'),
#  ('Randle, Chasson', 'Stanford'),
#  ('Rathan-Mayes, Xavier', 'Florida State'),
#  ('Sessions, Ramon', 'Nevada'),
#  ('Thomas, Lance', 'Duke'),
#  ('Anderson, Justin', 'Virginia'),
#  ('Bayless, Jerryd', 'Arizona'),
#  ('Blackmon Jr., James', 'Indiana'),
#  ('Covington, Robert', 'Tennessee State'),
#  ('Embiid, Joel', 'Kansas'),
#  ('Fultz, Markelle', 'Washington'),
#  ('Holmes, Richaun', 'Bowling Green'),
#  ('Johnson, Amir', 'Westchester HS (CA)'),
#  ('Korkmaz, Furkan', 'Turkey'),
#  (u'Luwawu-Cabarrot, Timoth\xe9', 'France'),
#  ('McAdoo, James Michael', 'North Carolina'),
#  ('McConnell, T. J.', 'Arizona'),
#  ('Okafor, Jahlil', 'Duke'),
#  ('Redick, J. J.', 'Duke'),
#  (u'\u0160ari\u0107, Dario', 'Croatia'),
#  ('Simmons, Ben', 'LSU'),
#  ('Stauskas, Nik', 'Michigan'),
#  ('Anunoby, OG', 'Indiana'),
#  ('Brown, Lorenzo', 'North Carolina State'),
#  ('Caboclo, Bruno', 'Brazil'),
#  ('DeRozan, DeMar', 'Southern California'),
#  ('Ibaka, Serge', 'Republic of the Congo'),
#  ('Lowry, Kyle', 'Villanova'),
#  ('McDaniels, K. J.', 'Clemson'),
#  ('McKinnie, Alfonzo', 'Green Bay'),
#  ('Meeks, Kennedy', 'North Carolina'),
#  ('Miles, C. J.', 'Skyline HS (TX)'),
#  ('Miller, Malcolm', 'Holy Cross'),
#  ('Nogueira, Lucas', 'Brazil'),
#  ('Poeltl, Jakob', 'Utah'),
#  ('Powell, Norman', 'UCLA'),
#  ('Siakam, Pascal', 'New Mexico State'),
#  (u'Valan\u010di\u016bnas, Jonas', 'Lithuania'),
#  ('VanVleet, Fred', 'Wichita State'),
#  ('Wiltjer, Kyle', 'Gonzaga'),
#  ('Wright, Delon', 'Utah'),
#  ('Arcidiacono, Ryan', 'Villanova'),
#  ('Blakeney, Antonio', 'LSU'),
#  ('Dunn, Kris', 'Providence'),
#  (u'Fel\xedcio, Cristiano', 'Notre Dame'),
#  ('Grant, Jerian', 'Washington'),
#  ('Holiday, Justin', 'UCLA'),
#  ('LaVine, Zach', 'Stanford'),
#  ('Lopez, Robin', 'Arizona'),
#  ('Markkanen, Lauri', 'Spain'),
#  (u'Miroti\u0107, Nikola', 'Cal Poly San Luis Obispo'),
#  ('Nwaba, David', 'Murray State'),
#  ('Payne, Cameron', 'Arkansas'),
#  ('Portis, Bobby', 'Michigan State'),
#  ('Valentine, Denzel', 'Marquette'),
#  ('Wade, Dwyane', 'Germany'),
#  ('Zipser, Paul', 'Spain'),
#  (u'Calder\xf3n, Jos\xe9', 'Marquette'),
#  ('Crowder, Jae', 'Oakland'),
#  ('Felder, Kay', 'Arizona'),
#  ('Frye, Channing', 'Georgetown'),
#  ('Green, Jeff', 'St. Vincent-St. Mary HS (OH)'),
#  ('James, LeBron', 'Arizona'),
#  ('Jefferson, Richard', 'Creighton'),
#  ('Korver, Kyle', 'UCLA'),
#  ('Love, Kevin', 'Turkey'),
#  ('Osman, Cedi', 'Memphis'),
#  ('Rose, Derrick', 'Georgia Tech'),
#  ('Shumpert, Iman', "Saint Benedict's Preparatory (NJ)"),
#  ('Smith, J. R.', 'Cape Verde'),
#  ('Tavares, Walter', 'Washington'),
#  ('Thomas, Isaiah', 'Texas'),
#  ('Thompson, Tristan', 'Croatia'),
#  (u'\u017di\u017ei\u0107, Ante', 'Texas'),
#  ('Bradley, Avery', 'North Carolina'),
#  ('Bullock, Reggie', 'Connecticut'),
#  ('Drummond, Andre', 'Marquette'),
#  ('Ellenson, Henry', "Saint Joseph's"),
#  ('Galloway, Langston', 'Tennessee'),
#  ('Harris, Tobias', 'Boston College'),
#  ('Jackson, Reggie', 'Arizona'),
#  ('Johnson, Stanley', 'Duke'),
#  ('Kennard, Luke', 'Wisconsin'),
#  ('Leuer, Jon', 'Serbia'),
#  (u'Marjanovi\u0107, Boban', 'Westchester CC'),
#  ('Montero, Luis', 'Oregon State'),
#  ('Moreland, Eric', 'Wake Forest'),
#  ('Smith, Ish', 'Creighton'),
#  ('Tolliver, Anthony', 'UCLA'),
#  ('Anigbogu, Ike', 'Croatia'),
#  (u'Bogdanovi\u0107, Bojan', 'UCLA'),
#  ('Collison, Darren', 'Prentiss HS (MS)'),
#  ('Jefferson, Al', 'Texas'),
#  ('Joseph, Cory', 'UCLA'),
#  ('Leaf, T. J.', 'Southern Methodist'),
#  ('Moore, Ben', 'Indiana'),
#  ('Oladipo, Victor', 'Kentucky'),
#  ('Poythress, Alex', 'Michigan'),
#  ('Robinson, Glenn', 'Gonzaga'),
#  ('Sabonis, Domantas', 'Cincinnati'),
#  ('Stephenson, Lance', 'Xavier'),
#  ('Sumner, Edmond', 'Texas'),
#  ('Turner, Myles', 'Georgia'),
#  ('Wilkins, Damien', 'Oregon'),
#  ('Young, Joe', 'Georgia Tech'),
#  ('Young, Thaddeus', 'Greece'),
#  ('Antetokounmpo, Giannis', 'Virginia'),
#  ('Brogdon, Malcolm', 'Southern Methodist'),
#  ('Brown, Sterling', "Saint Mary's"),
#  ('Dellavedova, Matthew', 'Washington'),
#  ('Hawes, Spencer', 'North Carolina'),
#  ('Henson, John', 'Wisconsin'),
#  ('Koenig, Bronson', 'Orangeville Prep (CAN)'),
#  ('Maker, Thon', 'Texas A&M'),
#  ('Middleton, Khris', 'Georgetown'),
#  ('Monroe, Greg', 'Utah State'),
#  ('Moore, Jalen', 'Duke'),
#  ('Parker, Jabari', 'Oregon State'),
#  ('Payton II, Gary', 'New Mexico'),
#  ('Snell, Tony', 'Bosnia and Herzegovina'),
#  (u'Teletovi\u0107, Mirza', 'UNLV'),
#  ('Vaughn, Rashad', 'Michigan'),
#  ('Wilson, D. J.', 'Nevada'),
#  ('Babbitt, Luke', 'Old Dominion'),
#  ('Bazemore, Kent', 'Italy'),
#  ('Belinelli, Marco', "Saint Joseph's"),
#  ("Bembry, DeAndre'", 'Argentina'),
#  (u'Brussino, Nicol\xe1s', 'Wake Forest'),
#  ('Collins, John', 'Southern California'),
#  ('Dedmon, Dewayne', 'Virginia Tech'),
#  ('Delaney, Malcolm', 'Oregon'),
#  ('Dorsey, Tyler', 'Turkey'),
#  (u'\u0130lyasova, Ersan', 'Bucknell'),
#  ('Muscala, Mike', 'Duke'),
#  ('Plumlee, Miles', 'Baylor'),
#  ('Prince, Taurean', 'Germany'),
#  (u'Schr\xf6der, Dennis', 'Florida State'),
#  ('Bacon, Dwayne', 'France'),
#  ('Batum, Nicolas', 'Syracuse'),
#  ('Carter-Williams, Michael', 'Virginia Commonwealth'),
#  ('Graham, Treveon', 'North Carolina'),
#  ('Hicks, Isaiah', 'Southwest Atlanta Christian Academy'),
#  ('Howard, Dwight', 'Wisconsin'),
#  ('Kaminsky, Frank', 'Kentucky'),
#  ('Kidd-Gilchrist, Michael', 'Connecticut'),
#  ('Lamb, Jeremy', 'Louisville'),
#  ('Mathiang, Mangok', 'Kentucky'),
#  ('Monk, Malik', 'LSU'),
#  ("O'Bryant, Johnny", 'North Carolina'),
#  ('Paige, Marcus', u'Texas\u2013El Paso'),
#  ('Stone, Julyan', 'Connecticut'),
#  ('Walker, Kemba', 'North Carolina'),
#  ('Williams, Marvin', 'Northeastern'),
#  ('Williams, T. J.', 'Indiana'),
#  ('Zeller, Cody', 'Kentucky'),
#  ('Adebayo, Bam', 'Slovenia'),
#  (u'Dragi\u0107, Goran', 'North Carolina'),
#  ('Ellington, Wayne', 'Purdue'),
#  ('Hammons, A. J.', 'Florida'),
#  ('Haslem, Udonis', 'Wake Forest'),
#  ('Johnson, James', 'Fresno State'),
#  ('Johnson, Tyler', 'Kansas State'),
#  ('McGruder, Rodney', 'LSU'),
#  ('Mickey, Jordan', 'Gonzaga'),
#  ('Olynyk, Kelly', 'Tennessee'),
#  ('Richardson, Josh', 'Syracuse'),
#  ('Waiters, Dion', 'Michigan'),
#  ('Walton, Derrick', 'Florida State'),
#  ('White, Okaro', 'Marshall'),
#  ('Whiteside, Hassan', 'Central Florida'),
#  ('Williams, Matt', 'Duke'),
#  ('Winslow, Justise', 'UCLA'),
#  ('Afflalo, Arron', 'Texas'),
#  ('Augustin, D. J.', 'UNLV'),
#  ('Birch, Khem', 'DR Congo'),
#  ('Biyombo, Bismack', 'France'),
#  ('Fournier, Evan', 'Arizona'),
#  ('Gordon, Aaron', 'Croatia'),
#  ('Hezonja, Mario', 'Florida State'),
#  ('Isaac, Jonathan', 'Kansas State'),
#  ('Iwundu, Wesley', 'Butler'),
#  ('Mack, Shelvin', 'Michigan State'),
#  ('Payne, Adreian', u'Louisiana\u2013Lafayette'),
#  ('Payton, Elfrid', 'Washington'),
#  ('Ross, Terrence', 'Houston'),
#  ('Simmons, Jonathon', 'Florida'),
#  ('Speights, Marreese', 'Southern California'),
#  (u'Vu\u010devi\u0107, Nikola', 'Florida'),
#  ('Beal, Bradley', 'Penn State'),
#  ('Frazier, Tim', 'Poland'),
#  ('Gortat, Marcin', 'France'),
#  ('Mahinmi, Ian', 'Miami (FL)'),
#  ('McClellan, Sheldon', 'Syracuse'),
#  ('McCullough, Chris', 'Kentucky'),
#  ('Meeks, Jodie', 'Kansas'),
#  ('Morris, Markieff', 'Villanova'),
#  ('Ochefu, Daniel', 'Kansas'),
#  ('Oubre Jr., Kelly', 'Georgetown'),
#  ('Porter, Otto', 'Florida'),
#  ('Robinson, Devin', 'Czech Republic'),
#  (u'Satoransk\xfd, Tom\xe1\u0161', 'Virginia'),
#  ('Scott, Mike', 'Colorado State'),
#  ('Smith, Jason', 'Kentucky'),
#  ('Wall, John', 'Pittsburgh'),
#  ('Young, Michael', 'Arizona'),
#  ('Ashley, Brandon', 'Northeastern'),
#  ('Barea, J. J.', 'North Carolina'),
#  ('Barnes, Harrison', 'Colorado State'),
#  ('Clavell, Gian', 'Duke'),
#  ('Curry, Seth', 'South Carolina'),
#  ('Dozier, P. J.', 'Indiana'),
#  ('Ferrell, Yogi', 'Florida'),
#  ('Finney-Smith, Dorian', 'Wisconsin'),
#  ('Harris, Devin', 'Germany'),
#  ('Kleber, Maxi', 'Marquette'),
#  ('Matthews, Wesley', 'Duke'),
#  ('McRoberts, Josh', 'Tunisia'),
#  ('Mejri, Salah', 'Baylor'),
#  ('Motley, Johnathan', 'Kentucky'),
#  ('Noel, Nerlens', 'Germany'),
#  ('Nowitzki, Dirk', 'Stanford'),
#  ('Powell, Dwight', 'North Carolina State'),
#  ('Smith Jr., Dennis', 'Villanova'),
#  ('Wayns, Maalik', 'Kansas'),
#  ('Withey, Jeff', 'UC Berkeley'),
#  ('Anderson, Ryan', 'UCLA'),
#  ('Ariza, Trevor', 'Kansas'),
#  ('Black, Tarik', 'INSEP (FRA)'),
#  ('Capela, Clint', 'Indiana'),
#  ('Gordon, Eric', 'Arizona State'),
#  ('Harden, James', 'Germany'),
#  ('Hartenstein, Isaiah', 'Notre Dame'),
#  ('Jackson, Demetrius', u'Louisiana\u2013Lafayette'),
#  ('Long, Shawn', 'UCLA'),
#  ('Mbah a Moute, Luc', 'Brazil'),
#  (u'Nen\xea', 'Nevada'),
#  ('Oliver, Cameron', 'Louisville'),
#  ('Onuaku, Chinanu', 'Wake Forest'),
#  ('Paul, Chris', 'LSU'),
#  ('Quarterman, Tim', 'Texas'),
#  ('Taylor, Isaiah', 'Texas'),
#  ('Tucker, P. J.', 'Indiana'),
#  ('Williams, Troy', 'China'),
#  ('Zhou Qi', 'Vanderbilt'),
#  ('Baldwin, Wade', 'Oregon'),
#  ('Brooks, Dillon', 'Kansas'),
#  ('Chalmers, Mario', 'Ohio State'),
#  ('Conley, Mike', 'Virginia Commonwealth'),
#  ('Daniels, Troy', 'Michigan State'),
#  ('Davis, Deyonta', 'Long Beach State'),
#  ('Ennis, James', 'Memphis'),
#  ('Evans, Tyreke', 'Lausanne CS (TN)'),
#  ('Gasol, Marc', 'Alabama'),
#  ('Green, JaMychal', 'Kentucky'),
#  ('Harrison, Andrew', 'LSU'),
#  ('Martin, Jarell', 'Kansas'),
#  ('McLemore, Ben', 'Northern Iowa'),
#  ('Morgan, Jeremy', 'Florida'),
#  ('Parsons, Chandler', 'UC Berkeley'),
#  ('Rabb, Ivan', 'Kansas'),
#  ('Selden, Wayne', 'Arizona'),
#  ('Simmons, Kobi', 'North Carolina'),
#  ('Wright, Brandan', 'Serbia'),
#  ('Zagorac, Rade', 'INSEP (FRA)'),
#  (u'Ajin\xe7a, Alexis', 'Turkey'),
#  (u'A\u015f\u0131k, \xd6mer', 'Belmont'),
#  ('Clark, Ian', 'Dayton'),
#  ('Cooke, Charles', 'Kentucky'),
#  ('Cousins, DeMarcus', 'Xavier'),
#  ('Crawford, Jordan', 'Kentucky'),
#  ('Davis, Anthony', 'Kansas'),
#  ('Diallo, Cheick', 'Arizona'),
#  ('Hill, Solomon', 'UCLA'),
#  ('Holiday, Jrue', 'Duke'),
#  ('Jackson, Frank', 'Texas A&M'),
#  ('Jones, Jalen', 'Kentucky'),
#  ('Miller, Darius', 'Purdue'),
#  ("Moore, E'Twaun", 'Washington'),
#  ('Pondexter, Quincy', 'Kentucky'),
#  ('Rondo, Rajon', 'Texas'),
#  ('Aldridge, LaMarcus', 'UCLA'),
#  ('Anderson, Kyle', 'Latvia'),
#  (u'Bert\u0101ns, D\u0101vis', 'Clemson'),
#  ('Blossomgame, Jaron', 'Michigan State'),
#  ('Costello, Matt', 'Michigan State'),
#  ('Forbes, Bryn', 'Spain'),
#  ('Gasol, Pau', 'Connecticut'),
#  ('Gay, Rudy', 'Argentina'),
#  (u'Gin\xf3bili, Manu', 'North Carolina'),
#  ('Green, Danny', 'France'),
#  ('Lauvergne, Joffrey', 'San Diego State'),
#  ('Leonard, Kawhi', "Saint Mary's"),
#  ('Mills, Patty', 'Washington'),
#  ('Murray, Dejounte', 'INSEP (FRA)'),
#  ('Parker, Tony', 'Illinois'),
#  ('Paul, Brandon', 'Virginia'),
#  ('Perrantes, London', 'Colorado'),
#  ('White, Derrick', 'Kansas'),
#  ('Arthur, Darrell', 'Memphis'),
#  ('Barton, Will', 'Florida State'),
#  ('Beasley, Malik', 'DePaul'),
#  ('Chandler, Wilson', 'USC Upstate'),
#  ('Craig, Torrey', 'Morehead State'),
#  ('Faried, Kenneth', 'Michigan State'),
#  ('Harris, Gary', 'Spain'),
#  (u'Hernang\xf3mez, Juan', 'Serbia'),
#  (u'Joki\u0107, Nikola', 'Syracuse'),
#  ('Lydon, Tyler', 'Kentucky'),
#  ('Lyles, Trey', 'Louisiana Tech'),
#  ('Millsap, Paul', 'Iowa State'),
#  (u'Morris, Mont\xe9', 'Prime Prep Academy (TX)'),
#  ('Mudiay, Emmanuel', 'Kentucky'),
#  ('Murray, Jamal', "Saint Joseph's"),
#  ('Nelson, Jameer', 'Duke'),
#  ('Plumlee, Mason', 'Kansas'),
#  ('Aldrich, Cole', 'Serbia'),
#  ('Bjelica, Nemanja', 'Stanford'),
#  ('Brown, Anthony', 'Marquette'),
#  ('Butler, Jimmy', 'Michigan'),
#  ('Crawford, Jamal', 'Louisville'),
#  ('Dieng, Gorgui', 'Georgia Tech'),
#  ('Georges-Hunt, Marcus', 'Southern California'),
#  ('Gibson, Taj', 'Duke'),
#  ('Jones, Tyus', 'Creighton'),
#  ('Patton, Justin', 'Wake Forest'),
#  ('Teague, Jeff', 'Kentucky'),
#  ('Towns, Karl-Anthony', 'Kansas'),
#  ('Wiggins, Andrew', 'Spain'),
#  (u'Abrines, \xc1lex', 'Pittsburgh'),
#  ('Adams, Steven', 'Xavier'),
#  ('Christon, Semaj', 'Kansas'),
#  ('Collison, Nick', 'North Carolina'),
#  ('Felton, Raymond', 'Fresno State'),
#  ('Ferguson, Terrance', 'Syracuse'),
#  ('George, Paul', 'Connecticut'),
#  ('Grant, Jerami', 'Stanford'),
#  ('Hamilton, Daniel', 'Kentucky'),
#  ('Huestis, Josh', 'Kentucky'),
#  ('Johnson, Dakari', 'Creighton'),
#  ('Kanter, Enes', 'Kentucky'),
#  ('McDermott, Doug', 'Colorado'),
#  ('Patterson, Patrick', 'Duke'),
#  (u'Roberson, Andr\xe9', 'UCLA'),
#  ('Singler, Kyle', 'Wake Forest'),
#  ('Westbrook, Russell', 'Gonzaga'),
#  ('Aminu, Al-Farouq', 'Notre Dame'),
#  ('Collins, Zach', 'North Carolina'),
#  ('Connaughton, Pat', "St. John's"),
#  ('Davis, Ed', 'Maryland'),
#  ('Harkless, Maurice', 'Illinois'),
#  ('Layman, Jake', 'Weber State'),
#  ('Leonard, Meyers', 'Lehigh'),
#  ('Lillard, Damian', 'Connecticut'),
#  ('McCollum, C. J.', 'Bosnia and Herzegovina'),
#  ('Napier, Shabazz', 'Purdue'),
#  (u'Nurki\u0107, Jusuf', 'Ohio State'),
#  ('Swanigan, Caleb', 'Indiana'),
#  ('Turner, Evan', 'Washington'),
#  ('Vonleh, Noah', 'Weber State'),
#  ('Wilcox, C. J.', 'North Carolina'),
#  ('Bolomboy, Joel', 'Colorado'),
#  ('Bradley, Tony', 'Lake Ginninderra (AUS)'),
#  ('Burks, Alec', 'Georgia Tech'),
#  ('Exum, Dante', 'France'),
#  ('Favors, Derrick', 'Campbell'),
#  ('Gobert, Rudy', 'Duke'),
#  ('Griffin, Eric', 'Lake Ginninderra (AUS)'),
#  ('Hood, Rodney', 'Sweden'),
#  ('Ingles, Joe', 'Arkansas'),
#  ('Jerebko, Jonas', 'Louisville'),
#  ('Johnson, Joe', 'Brazil'),
#  ('Mitchell, Donovan', 'Baylor'),
#  ('Neto, Raul', 'Spain'),
#  ("O'Neale, Royce", 'Switzerland'),
#  ('Rubio, Ricky', 'Baylor'),
#  ('Sefolosha, Thabo', 'Gonzaga'),
#  ('Udoh, Ekpe', 'Oregon'),
#  ('Williams-Goss, Nigel', 'Oregon'),
#  ('Bell, Jordan', 'Israel'),
#  ('Boucher, Chris', 'Davidson'),
#  ('Casspi, Omri', 'Texas'),
#  ('Curry, Stephen', 'Michigan State'),
#  ('Durant, Kevin', 'Arizona'),
#  ('Green, Draymond', 'Vanderbilt'),
#  ('Iguodala, Andre', 'Peoria Central HS (IL)'),
#  ('Jones, Damian', 'UCLA'),
#  ('Livingston, Shaun', 'UNLV'),
#  ('Looney, Kevon', 'Nevada'),
#  ('McCaw, Patrick', 'Georgia'),
#  ('McGee, JaVale', 'Washington State'),
#  ('Pachulia, Zaza', 'Xavier'),
#  ('Thompson, Klay', 'Southern California'),
#  ('West, David', 'Arkansas'),
#  ('Young, Nick', 'Wisconsin'),
#  ('Beverley, Patrick', 'Oklahoma State'),
#  ('Dekker, Sam', 'Italy'),
#  ('Evans, Jawun', 'Oklahoma'),
#  ('Gallinari, Danilo', 'Louisville'),
#  ('Griffin, Blake', 'North Carolina'),
#  ('Harrell, Montrezl', 'Syracuse'),
#  ('Johnson, Brice', 'Texas A&M'),
#  ('Johnson, Wesley', 'Kentucky'),
#  ('Jordan, DeAndre', 'Saint Louis'),
#  ('Liggins, DeAndre', 'Duke'),
#  ('Reed, Willie', 'Serbia'),
#  ('Rivers, Austin', 'South Carolina'),
#  (u'Teodosi\u0107, Milo\u0161', 'South Gwinnett HS (GA)'),
#  ('Thornwell, Sindarius', 'Marquette'),
#  ('Williams, Lou', 'UCLA'),
#  ('Wilson, Jamil', 'Notre Dame'),
#  ('Ball, Lonzo', 'Marquette'),
#  ('Beachem, V. J.', 'Florida'),
#  ('Blue, Vander', 'Indiana'),
#  ('Brewer, Corey', 'Georgia'),
#  ('Bryant, Thomas', 'Texas A&M'),
#  ('Caldwell-Pope, Kentavious', 'Missouri'),
#  ('Caruso, Alex', 'Duke'),
#  ('Clarkson, Jordan', 'Syracuse'),
#  ('Deng, Luol', 'Villanova'),
#  ('Ennis, Tyler', 'Duke'),
#  ('Hart, Josh', 'Utah'),
#  ('Ingram, Brandon', 'Stanford'),
#  ('Kuzma, Kyle', 'Wyoming'),
#  ('Lopez, Brook', 'Kentucky'),
#  ('Nance Jr., Larry', 'Virginia Commonwealth'),
#  ('Randle, Julius', 'UNLV'),
#  (u'Weber, Briant\xe9', 'Croatia'),
#  ('Zimmerman, Stephen', 'Croatia'),
#  ('Zubac, Ivica', 'Kentucky'),
#  ('Bender, Dragan', 'Kentucky'),
#  ('Bledsoe, Eric', 'Manuel Dominguez HS (CA)'),
#  ('Booker, Devin', 'Washington'),
#  ('Chandler, Tyson', 'Boston College'),
#  ('Chriss, Marquese', 'Kansas'),
#  ('Dudley, Jared', 'Lamar'),
#  ('Jackson, Josh', 'UNLV'),
#  ('James, Mike', 'Kentucky'),
#  ('Jones, Derrick', 'Maryland'),
#  ('Knight, Brandon', u'Alabama\u2013Birmingham'),
#  ('Len, Alex', 'Valparaiso'),
#  ('Millsap, Elijah', 'Miami (FL)'),
#  ('Peters, Alec', 'Kentucky'),
#  ('Reed, Davon', 'North Carolina State'),
#  ('Ulis, Tyler', 'UC Santa Barbara'),
#  ('Warren, T. J.', 'Serbia'),
#  ('Williams, Alan', 'North Carolina'),
#  (u'Bogdanovi\u0107, Bogdan', 'Kentucky'),
#  ('Carter, Vince', 'Notre Dame'),
#  ('Cauley-Stein, Willie', 'Kentucky'),
#  ('Cooley, Jack', 'Duke'),
#  ("Fox, De'Aaron", 'Oklahoma'),
#  ('Giles, Harry', 'IUPUI'),
#  ('Hield, Buddy', 'North Carolina'),
#  ('Hill, George', 'Ohio State'),
#  ('Jackson, Justin', 'Kentucky'),
#  ('Koufos, Kosta', 'Kansas'),
#  (u'Labissi\xe8re, Skal', 'American School (GRE)'),
#  ('Mason III, Frank', 'Michigan State'),
#  ('Papagiannis, Georgios', 'Syracuse'),
#  ('Randolph, Zach', "St. John's"),
#  ('Richardson, Malachi', 'LSU')]

# %% [markdown]
# The data collected does not contain all the players on the website. What is clear here is two players (**Temple, Garrett; Tolliver, Anthony**) are missing. Also, the player names and their colleges do not match.
#
# The following players' **from** information is included in not **a** tag but **td[7]** tag
#
# - Felício, Cristiano
# - Kanter, Enes

# %%
name = data.xpath('//tr/td[3]/a/text()')
#multiple Xpaths using |
school = data.xpath('//tr/td[7]/a/text() | //tr/td[7]/text()')

finaldata = zip(name, school)
finaldata
# Out:
# [('Allen, Kadeem', 'Arizona'),
#  ('Baynes, Aron', 'Washington State'),
#  ('Bird, Jabari', 'UC Berkeley'),
#  ('Brown, Jaylen', 'UC Berkeley'),
#  ('Hayward, Gordon', 'Butler'),
#  ('Horford, Al', 'Florida'),
#  ('Irving, Kyrie', 'Duke'),
#  ('Larkin, Shane', 'Miami (FL)'),
#  ('Morris, Marcus', 'Kansas'),
#  ('Nader, Abdel', 'Iowa State'),
#  ('Ojeleye, Semi', 'Southern Methodist'),
#  ('Rozier, Terry', 'Louisville'),
#  ('Smart, Marcus', 'Oklahoma State'),
#  ('Tatum, Jayson', 'Duke'),
#  ('Theis, Daniel', 'Germany'),
#  ('Yabusele, Guerschon', 'France'),
#  ('Acy, Quincy', 'Baylor'),
#  ('Allen, Jarrett', 'Texas'),
#  ('Booker, Trevor', 'Clemson'),
#  ('Carroll, DeMarre', 'Missouri'),
#  ('Crabbe, Allen', 'UC Berkeley'),
#  ('Dinwiddie, Spencer', 'Colorado'),
#  ('Doyle, Milton', 'Loyola (IL)'),
#  ('Harris, Joe', 'Virginia'),
#  ('Hollis-Jefferson, Rondae', 'Arizona'),
#  ('Kilpatrick, Sean', 'Cincinnati'),
#  ('LeVert, Caris', 'Michigan'),
#  ('Lin, Jeremy', 'Harvard'),
#  ('Mozgov, Timofey', 'Russia'),
#  ('Ouattara, Yakuba', 'Ghana'),
#  ('Senglin, Jeremy', 'Weber State'),
#  ("Russell, D'Angelo", 'Ohio State'),
#  ('Whitehead, Isaiah', 'Seton Hall'),
#  ('Wiley, Jacob', 'Eastern Washington'),
#  ('Anthony, Carmelo', 'Syracuse'),
#  ('Artis, Jamel', 'Pittsburgh'),
#  ('Baker, Ron', 'Wichita State'),
#  ('Beasley, Michael', 'Kansas State'),
#  ('Dotson, Damyean', 'Houston'),
#  ('Hardaway, Tim', 'Michigan'),
#  ('Hayes, Nigel', 'Wisconsin'),
#  (u'Hernang\xf3mez, Willy', 'Spain'),
#  ('Jaramaz, Ognjen', 'Serbia'),
#  ('Kornet, Luke', 'Vanderbilt'),
#  ('Kuzminskas, Mindaugas', 'Lithuania'),
#  ('Lee, Courtney', 'Western Kentucky'),
#  ('Noah, Joakim', 'Florida'),
#  ('Ntilikina, Frank', 'France'),
#  ("O'Quinn, Kyle", 'Norfolk State'),
#  (u'Porzi\u0146\u0123is, Kristaps', 'Latvia'),
#  ('Randle, Chasson', 'Stanford'),
#  ('Rathan-Mayes, Xavier', 'Florida State'),
#  ('Sessions, Ramon', 'Nevada'),
#  ('Thomas, Lance', 'Duke'),
#  ('Anderson, Justin', 'Virginia'),
#  ('Bayless, Jerryd', 'Arizona'),
#  ('Blackmon Jr., James', 'Indiana'),
#  ('Covington, Robert', 'Tennessee State'),
#  ('Embiid, Joel', 'Kansas'),
#  ('Fultz, Markelle', 'Washington'),
#  ('Holmes, Richaun', 'Bowling Green'),
#  ('Johnson, Amir', 'Westchester HS (CA)'),
#  ('Korkmaz, Furkan', 'Turkey'),
#  (u'Luwawu-Cabarrot, Timoth\xe9', 'France'),
#  ('McAdoo, James Michael', 'North Carolina'),
#  ('McConnell, T. J.', 'Arizona'),
#  ('Okafor, Jahlil', 'Duke'),
#  ('Redick, J. J.', 'Duke'),
#  (u'\u0160ari\u0107, Dario', 'Croatia'),
#  ('Simmons, Ben', 'LSU'),
#  ('Stauskas, Nik', 'Michigan'),
#  ('Anunoby, OG', 'Indiana'),
#  ('Brown, Lorenzo', 'North Carolina State'),
#  ('Caboclo, Bruno', 'Brazil'),
#  ('DeRozan, DeMar', 'Southern California'),
#  ('Ibaka, Serge', 'Republic of the Congo'),
#  ('Lowry, Kyle', 'Villanova'),
#  ('McDaniels, K. J.', 'Clemson'),
#  ('McKinnie, Alfonzo', 'Green Bay'),
#  ('Meeks, Kennedy', 'North Carolina'),
#  ('Miles, C. J.', 'Skyline HS (TX)'),
#  ('Miller, Malcolm', 'Holy Cross'),
#  ('Nogueira, Lucas', 'Brazil'),
#  ('Poeltl, Jakob', 'Utah'),
#  ('Powell, Norman', 'UCLA'),
#  ('Siakam, Pascal', 'New Mexico State'),
#  (u'Valan\u010di\u016bnas, Jonas', 'Lithuania'),
#  ('VanVleet, Fred', 'Wichita State'),
#  ('Wiltjer, Kyle', 'Gonzaga'),
#  ('Wright, Delon', 'Utah'),
#  ('Arcidiacono, Ryan', 'Villanova'),
#  ('Blakeney, Antonio', 'LSU'),
#  ('Dunn, Kris', 'Providence'),
#  (u'Fel\xedcio, Cristiano', 'CCSE Prep (CA)'),
#  ('Grant, Jerian', 'Notre Dame'),
#  ('Holiday, Justin', 'Washington'),
#  ('LaVine, Zach', 'UCLA'),
#  ('Lopez, Robin', 'Stanford'),
#  ('Markkanen, Lauri', 'Arizona'),
#  (u'Miroti\u0107, Nikola', 'Spain'),
#  ('Nwaba, David', 'Cal Poly San Luis Obispo'),
#  ('Payne, Cameron', 'Murray State'),
#  ('Portis, Bobby', 'Arkansas'),
#  ('Valentine, Denzel', 'Michigan State'),
#  ('Wade, Dwyane', 'Marquette'),
#  ('Zipser, Paul', 'Germany'),
#  (u'Calder\xf3n, Jos\xe9', 'Spain'),
#  ('Crowder, Jae', 'Marquette'),
#  ('Felder, Kay', 'Oakland'),
#  ('Frye, Channing', 'Arizona'),
#  ('Green, Jeff', 'Georgetown'),
#  ('James, LeBron', 'St. Vincent-St. Mary HS (OH)'),
#  ('Jefferson, Richard', 'Arizona'),
#  ('Korver, Kyle', 'Creighton'),
#  ('Love, Kevin', 'UCLA'),
#  ('Osman, Cedi', 'Turkey'),
#  ('Rose, Derrick', 'Memphis'),
#  ('Shumpert, Iman', 'Georgia Tech'),
#  ('Smith, J. R.', "Saint Benedict's Preparatory (NJ)"),
#  ('Tavares, Walter', 'Cape Verde'),
#  ('Thomas, Isaiah', 'Washington'),
#  ('Thompson, Tristan', 'Texas'),
#  (u'\u017di\u017ei\u0107, Ante', 'Croatia'),
#  ('Bradley, Avery', 'Texas'),
#  ('Bullock, Reggie', 'North Carolina'),
#  ('Drummond, Andre', 'Connecticut'),
#  ('Ellenson, Henry', 'Marquette'),
#  ('Galloway, Langston', "Saint Joseph's"),
#  ('Harris, Tobias', 'Tennessee'),
#  ('Jackson, Reggie', 'Boston College'),
#  ('Johnson, Stanley', 'Arizona'),
#  ('Kennard, Luke', 'Duke'),
#  ('Leuer, Jon', 'Wisconsin'),
#  (u'Marjanovi\u0107, Boban', 'Serbia'),
#  ('Montero, Luis', 'Westchester CC'),
#  ('Moreland, Eric', 'Oregon State'),
#  ('Smith, Ish', 'Wake Forest'),
#  ('Tolliver, Anthony', 'Creighton'),
#  ('Anigbogu, Ike', 'UCLA'),
#  (u'Bogdanovi\u0107, Bojan', 'Croatia'),
#  ('Collison, Darren', 'UCLA'),
#  ('Jefferson, Al', 'Prentiss HS (MS)'),
#  ('Joseph, Cory', 'Texas'),
#  ('Leaf, T. J.', 'UCLA'),
#  ('Moore, Ben', 'Southern Methodist'),
#  ('Oladipo, Victor', 'Indiana'),
#  ('Poythress, Alex', 'Kentucky'),
#  ('Robinson, Glenn', 'Michigan'),
#  ('Sabonis, Domantas', 'Gonzaga'),
#  ('Stephenson, Lance', 'Cincinnati'),
#  ('Sumner, Edmond', 'Xavier'),
#  ('Turner, Myles', 'Texas'),
#  ('Wilkins, Damien', 'Georgia'),
#  ('Young, Joe', 'Oregon'),
#  ('Young, Thaddeus', 'Georgia Tech'),
#  ('Antetokounmpo, Giannis', 'Greece'),
#  ('Brogdon, Malcolm', 'Virginia'),
#  ('Brown, Sterling', 'Southern Methodist'),
#  ('Dellavedova, Matthew', "Saint Mary's"),
#  ('Hawes, Spencer', 'Washington'),
#  ('Henson, John', 'North Carolina'),
#  ('Koenig, Bronson', 'Wisconsin'),
#  ('Maker, Thon', 'Orangeville Prep (CAN)'),
#  ('Middleton, Khris', 'Texas A&M'),
#  ('Monroe, Greg', 'Georgetown'),
#  ('Moore, Jalen', 'Utah State'),
#  ('Parker, Jabari', 'Duke'),
#  ('Payton II, Gary', 'Oregon State'),
#  ('Snell, Tony', 'New Mexico'),
#  (u'Teletovi\u0107, Mirza', 'Bosnia and Herzegovina'),
#  ('Vaughn, Rashad', 'UNLV'),
#  ('Wilson, D. J.', 'Michigan'),
#  ('Babbitt, Luke', 'Nevada'),
#  ('Bazemore, Kent', 'Old Dominion'),
#  ('Belinelli, Marco', 'Italy'),
#  ("Bembry, DeAndre'", "Saint Joseph's"),
#  (u'Brussino, Nicol\xe1s', 'Argentina'),
#  ('Collins, John', 'Wake Forest'),
#  ('Dedmon, Dewayne', 'Southern California'),
#  ('Delaney, Malcolm', 'Virginia Tech'),
#  ('Dorsey, Tyler', 'Oregon'),
#  (u'\u0130lyasova, Ersan', 'Turkey'),
#  ('Muscala, Mike', 'Bucknell'),
#  ('Plumlee, Miles', 'Duke'),
#  ('Prince, Taurean', 'Baylor'),
#  (u'Schr\xf6der, Dennis', 'Germany'),
#  ('Bacon, Dwayne', 'Florida State'),
#  ('Batum, Nicolas', 'France'),
#  ('Carter-Williams, Michael', 'Syracuse'),
#  ('Graham, Treveon', 'Virginia Commonwealth'),
#  ('Hicks, Isaiah', 'North Carolina'),
#  ('Howard, Dwight', 'Southwest Atlanta Christian Academy'),
#  ('Kaminsky, Frank', 'Wisconsin'),
#  ('Kidd-Gilchrist, Michael', 'Kentucky'),
#  ('Lamb, Jeremy', 'Connecticut'),
#  ('Mathiang, Mangok', 'Louisville'),
#  ('Monk, Malik', 'Kentucky'),
#  ("O'Bryant, Johnny", 'LSU'),
#  ('Paige, Marcus', 'North Carolina'),
#  ('Stone, Julyan', u'Texas\u2013El Paso'),
#  ('Walker, Kemba', 'Connecticut'),
#  ('Williams, Marvin', 'North Carolina'),
#  ('Williams, T. J.', 'Northeastern'),
#  ('Zeller, Cody', 'Indiana'),
#  ('Adebayo, Bam', 'Kentucky'),
#  (u'Dragi\u0107, Goran', 'Slovenia'),
#  ('Ellington, Wayne', 'North Carolina'),
#  ('Hammons, A. J.', 'Purdue'),
#  ('Haslem, Udonis', 'Florida'),
#  ('Johnson, James', 'Wake Forest'),
#  ('Johnson, Tyler', 'Fresno State'),
#  ('McGruder, Rodney', 'Kansas State'),
#  ('Mickey, Jordan', 'LSU'),
#  ('Olynyk, Kelly', 'Gonzaga'),
#  ('Richardson, Josh', 'Tennessee'),
#  ('Waiters, Dion', 'Syracuse'),
#  ('Walton, Derrick', 'Michigan'),
#  ('White, Okaro', 'Florida State'),
#  ('Whiteside, Hassan', 'Marshall'),
#  ('Williams, Matt', 'Central Florida'),
#  ('Winslow, Justise', 'Duke'),
#  ('Afflalo, Arron', 'UCLA'),
#  ('Augustin, D. J.', 'Texas'),
#  ('Birch, Khem', 'UNLV'),
#  ('Biyombo, Bismack', 'DR Congo'),
#  ('Fournier, Evan', 'France'),
#  ('Gordon, Aaron', 'Arizona'),
#  ('Hezonja, Mario', 'Croatia'),
#  ('Isaac, Jonathan', 'Florida State'),
#  ('Iwundu, Wesley', 'Kansas State'),
#  ('Mack, Shelvin', 'Butler'),
#  ('Payne, Adreian', 'Michigan State'),
#  ('Payton, Elfrid', u'Louisiana\u2013Lafayette'),
#  ('Ross, Terrence', 'Washington'),
#  ('Simmons, Jonathon', 'Houston'),
#  ('Speights, Marreese', 'Florida'),
#  (u'Vu\u010devi\u0107, Nikola', 'Southern California'),
#  ('Beal, Bradley', 'Florida'),
#  ('Frazier, Tim', 'Penn State'),
#  ('Gortat, Marcin', 'Poland'),
#  ('Mahinmi, Ian', 'France'),
#  ('McClellan, Sheldon', 'Miami (FL)'),
#  ('McCullough, Chris', 'Syracuse'),
#  ('Meeks, Jodie', 'Kentucky'),
#  ('Morris, Markieff', 'Kansas'),
#  ('Ochefu, Daniel', 'Villanova'),
#  ('Oubre Jr., Kelly', 'Kansas'),
#  ('Porter, Otto', 'Georgetown'),
#  ('Robinson, Devin', 'Florida'),
#  (u'Satoransk\xfd, Tom\xe1\u0161', 'Czech Republic'),
#  ('Scott, Mike', 'Virginia'),
#  ('Smith, Jason', 'Colorado State'),
#  ('Wall, John', 'Kentucky'),
#  ('Young, Michael', 'Pittsburgh'),
#  ('Ashley, Brandon', 'Arizona'),
#  ('Barea, J. J.', 'Northeastern'),
#  ('Barnes, Harrison', 'North Carolina'),
#  ('Clavell, Gian', 'Colorado State'),
#  ('Curry, Seth', 'Duke'),
#  ('Dozier, P. J.', 'South Carolina'),
#  ('Ferrell, Yogi', 'Indiana'),
#  ('Finney-Smith, Dorian', 'Florida'),
#  ('Harris, Devin', 'Wisconsin'),
#  ('Kleber, Maxi', 'Germany'),
#  ('Matthews, Wesley', 'Marquette'),
#  ('McRoberts, Josh', 'Duke'),
#  ('Mejri, Salah', 'Tunisia'),
#  ('Motley, Johnathan', 'Baylor'),
#  ('Noel, Nerlens', 'Kentucky'),
#  ('Nowitzki, Dirk', 'Germany'),
#  ('Powell, Dwight', 'Stanford'),
#  ('Smith Jr., Dennis', 'North Carolina State'),
#  ('Wayns, Maalik', 'Villanova'),
#  ('Withey, Jeff', 'Kansas'),
#  ('Anderson, Ryan', 'UC Berkeley'),
#  ('Ariza, Trevor', 'UCLA'),
#  ('Black, Tarik', 'Kansas'),
#  ('Capela, Clint', 'INSEP (FRA)'),
#  ('Gordon, Eric', 'Indiana'),
#  ('Harden, James', 'Arizona State'),
#  ('Hartenstein, Isaiah', 'Germany'),
#  ('Jackson, Demetrius', 'Notre Dame'),
#  ('Long, Shawn', u'Louisiana\u2013Lafayette'),
#  ('Mbah a Moute, Luc', 'UCLA'),
#  (u'Nen\xea', 'Brazil'),
#  ('Oliver, Cameron', 'Nevada'),
#  ('Onuaku, Chinanu', 'Louisville'),
#  ('Paul, Chris', 'Wake Forest'),
#  ('Quarterman, Tim', 'LSU'),
#  ('Taylor, Isaiah', 'Texas'),
#  ('Tucker, P. J.', 'Texas'),
#  ('Williams, Troy', 'Indiana'),
#  ('Zhou Qi', 'China'),
#  ('Baldwin, Wade', 'Vanderbilt'),
#  ('Brooks, Dillon', 'Oregon'),
#  ('Chalmers, Mario', 'Kansas'),
#  ('Conley, Mike', 'Ohio State'),
#  ('Daniels, Troy', 'Virginia Commonwealth'),
#  ('Davis, Deyonta', 'Michigan State'),
#  ('Ennis, James', 'Long Beach State'),
#  ('Evans, Tyreke', 'Memphis'),
#  ('Gasol, Marc', 'Lausanne CS (TN)'),
#  ('Green, JaMychal', 'Alabama'),
#  ('Harrison, Andrew', 'Kentucky'),
#  ('Martin, Jarell', 'LSU'),
#  ('McLemore, Ben', 'Kansas'),
#  ('Morgan, Jeremy', 'Northern Iowa'),
#  ('Parsons, Chandler', 'Florida'),
#  ('Rabb, Ivan', 'UC Berkeley'),
#  ('Selden, Wayne', 'Kansas'),
#  ('Simmons, Kobi', 'Arizona'),
#  ('Wright, Brandan', 'North Carolina'),
#  ('Zagorac, Rade', 'Serbia'),
#  (u'Ajin\xe7a, Alexis', 'INSEP (FRA)'),
#  (u'A\u015f\u0131k, \xd6mer', 'Turkey'),
#  ('Clark, Ian', 'Belmont'),
#  ('Cooke, Charles', 'Dayton'),
#  ('Cousins, DeMarcus', 'Kentucky'),
#  ('Crawford, Jordan', 'Xavier'),
#  ('Davis, Anthony', 'Kentucky'),
#  ('Diallo, Cheick', 'Kansas'),
#  ('Hill, Solomon', 'Arizona'),
#  ('Holiday, Jrue', 'UCLA'),
#  ('Jackson, Frank', 'Duke'),
#  ('Jones, Jalen', 'Texas A&M'),
#  ('Miller, Darius', 'Kentucky'),
#  ("Moore, E'Twaun", 'Purdue'),
#  ('Pondexter, Quincy', 'Washington'),
#  ('Rondo, Rajon', 'Kentucky'),
#  ('Aldridge, LaMarcus', 'Texas'),
#  ('Anderson, Kyle', 'UCLA'),
#  (u'Bert\u0101ns, D\u0101vis', 'Latvia'),
#  ('Blossomgame, Jaron', 'Clemson'),
#  ('Costello, Matt', 'Michigan State'),
#  ('Forbes, Bryn', 'Michigan State'),
#  ('Gasol, Pau', 'Spain'),
#  ('Gay, Rudy', 'Connecticut'),
#  (u'Gin\xf3bili, Manu', 'Argentina'),
#  ('Green, Danny', 'North Carolina'),
#  ('Lauvergne, Joffrey', 'France'),
#  ('Leonard, Kawhi', 'San Diego State'),
#  ('Mills, Patty', "Saint Mary's"),
#  ('Murray, Dejounte', 'Washington'),
#  ('Parker, Tony', 'INSEP (FRA)'),
#  ('Paul, Brandon', 'Illinois'),
#  ('Perrantes, London', 'Virginia'),
#  ('White, Derrick', 'Colorado'),
#  ('Arthur, Darrell', 'Kansas'),
#  ('Barton, Will', 'Memphis'),
#  ('Beasley, Malik', 'Florida State'),
#  ('Chandler, Wilson', 'DePaul'),
#  ('Craig, Torrey', 'USC Upstate'),
#  ('Faried, Kenneth', 'Morehead State'),
#  ('Harris, Gary', 'Michigan State'),
#  (u'Hernang\xf3mez, Juan', 'Spain'),
#  (u'Joki\u0107, Nikola', 'Serbia'),
#  ('Lydon, Tyler', 'Syracuse'),
#  ('Lyles, Trey', 'Kentucky'),
#  ('Millsap, Paul', 'Louisiana Tech'),
#  (u'Morris, Mont\xe9', 'Iowa State'),
#  ('Mudiay, Emmanuel', 'Prime Prep Academy (TX)'),
#  ('Murray, Jamal', 'Kentucky'),
#  ('Nelson, Jameer', "Saint Joseph's"),
#  ('Plumlee, Mason', 'Duke'),
#  ('Aldrich, Cole', 'Kansas'),
#  ('Bjelica, Nemanja', 'Serbia'),
#  ('Brown, Anthony', 'Stanford'),
#  ('Butler, Jimmy', 'Marquette'),
#  ('Crawford, Jamal', 'Michigan'),
#  ('Dieng, Gorgui', 'Louisville'),
#  ('Georges-Hunt, Marcus', 'Georgia Tech'),
#  ('Gibson, Taj', 'Southern California'),
#  ('Jones, Tyus', 'Duke'),
#  ('Patton, Justin', 'Creighton'),
#  ('Teague, Jeff', 'Wake Forest'),
#  ('Towns, Karl-Anthony', 'Kentucky'),
#  ('Wiggins, Andrew', 'Kansas'),
#  (u'Abrines, \xc1lex', 'Spain'),
#  ('Adams, Steven', 'Pittsburgh'),
#  ('Christon, Semaj', 'Xavier'),
#  ('Collison, Nick', 'Kansas'),
#  ('Felton, Raymond', 'North Carolina'),
#  ('Ferguson, Terrance', 'Advanced Prep International (TX)'),
#  ('George, Paul', 'Fresno State'),
#  ('Grant, Jerami', 'Syracuse'),
#  ('Hamilton, Daniel', 'Connecticut'),
#  ('Huestis, Josh', 'Stanford'),
#  ('Johnson, Dakari', 'Kentucky'),
#  ('Kanter, Enes', 'Kentucky'),
#  ('McDermott, Doug', 'Creighton'),
#  ('Patterson, Patrick', 'Kentucky'),
#  (u'Roberson, Andr\xe9', 'Colorado'),
#  ('Singler, Kyle', 'Duke'),
#  ('Westbrook, Russell', 'UCLA'),
#  ('Aminu, Al-Farouq', 'Wake Forest'),
#  ('Collins, Zach', 'Gonzaga'),
#  ('Connaughton, Pat', 'Notre Dame'),
#  ('Davis, Ed', 'North Carolina'),
#  ('Harkless, Maurice', "St. John's"),
#  ('Layman, Jake', 'Maryland'),
#  ('Leonard, Meyers', 'Illinois'),
#  ('Lillard, Damian', 'Weber State'),
#  ('McCollum, C. J.', 'Lehigh'),
#  ('Napier, Shabazz', 'Connecticut'),
#  (u'Nurki\u0107, Jusuf', 'Bosnia and Herzegovina'),
#  ('Swanigan, Caleb', 'Purdue'),
#  ('Turner, Evan', 'Ohio State'),
#  ('Vonleh, Noah', 'Indiana'),
#  ('Wilcox, C. J.', 'Washington'),
#  ('Bolomboy, Joel', 'Weber State'),
#  ('Bradley, Tony', 'North Carolina'),
#  ('Burks, Alec', 'Colorado'),
#  ('Exum, Dante', 'Lake Ginninderra (AUS)'),
#  ('Favors, Derrick', 'Georgia Tech'),
#  ('Gobert, Rudy', 'France'),
#  ('Griffin, Eric', 'Campbell'),
#  ('Hood, Rodney', 'Duke'),
#  ('Ingles, Joe', 'Lake Ginninderra (AUS)'),
#  ('Jerebko, Jonas', 'Sweden'),
#  ('Johnson, Joe', 'Arkansas'),
#  ('Mitchell, Donovan', 'Louisville'),
#  ('Neto, Raul', 'Brazil'),
#  ("O'Neale, Royce", 'Baylor'),
#  ('Rubio, Ricky', 'Spain'),
#  ('Sefolosha, Thabo', 'Switzerland'),
#  ('Udoh, Ekpe', 'Baylor'),
#  ('Williams-Goss, Nigel', 'Gonzaga'),
#  ('Bell, Jordan', 'Oregon'),
#  ('Boucher, Chris', 'Oregon'),
#  ('Casspi, Omri', 'Israel'),
#  ('Curry, Stephen', 'Davidson'),
#  ('Durant, Kevin', 'Texas'),
#  ('Green, Draymond', 'Michigan State'),
#  ('Iguodala, Andre', 'Arizona'),
#  ('Jones, Damian', 'Vanderbilt'),
#  ('Livingston, Shaun', 'Peoria Central HS (IL)'),
#  ('Looney, Kevon', 'UCLA'),
#  ('McCaw, Patrick', 'UNLV'),
#  ('McGee, JaVale', 'Nevada'),
#  ('Pachulia, Zaza', 'Georgia'),
#  ('Thompson, Klay', 'Washington State'),
#  ('West, David', 'Xavier'),
#  ('Young, Nick', 'Southern California'),
#  ('Beverley, Patrick', 'Arkansas'),
#  ('Dekker, Sam', 'Wisconsin'),
#  ('Evans, Jawun', 'Oklahoma State'),
#  ('Gallinari, Danilo', 'Italy'),
#  ('Griffin, Blake', 'Oklahoma'),
#  ('Harrell, Montrezl', 'Louisville'),
#  ('Johnson, Brice', 'North Carolina'),
#  ('Johnson, Wesley', 'Syracuse'),
#  ('Jordan, DeAndre', 'Texas A&M'),
#  ('Liggins, DeAndre', 'Kentucky'),
#  ('Reed, Willie', 'Saint Louis'),
#  ('Rivers, Austin', 'Duke'),
#  (u'Teodosi\u0107, Milo\u0161', 'Serbia'),
#  ('Thornwell, Sindarius', 'South Carolina'),
#  ('Williams, Lou', 'South Gwinnett HS (GA)'),
#  ('Wilson, Jamil', 'Marquette'),
#  ('Ball, Lonzo', 'UCLA'),
#  ('Beachem, V. J.', 'Notre Dame'),
#  ('Blue, Vander', 'Marquette'),
#  ('Brewer, Corey', 'Florida'),
#  ('Bryant, Thomas', 'Indiana'),
#  ('Caldwell-Pope, Kentavious', 'Georgia'),
#  ('Caruso, Alex', 'Texas A&M'),
#  ('Clarkson, Jordan', 'Missouri'),
#  ('Deng, Luol', 'Duke'),
#  ('Ennis, Tyler', 'Syracuse'),
#  ('Hart, Josh', 'Villanova'),
#  ('Ingram, Brandon', 'Duke'),
#  ('Kuzma, Kyle', 'Utah'),
#  ('Lopez, Brook', 'Stanford'),
#  ('Nance Jr., Larry', 'Wyoming'),
#  ('Randle, Julius', 'Kentucky'),
#  (u'Weber, Briant\xe9', 'Virginia Commonwealth'),
#  ('Zimmerman, Stephen', 'UNLV'),
#  ('Zubac, Ivica', 'Croatia'),
#  ('Bender, Dragan', 'Croatia'),
#  ('Bledsoe, Eric', 'Kentucky'),
#  ('Booker, Devin', 'Kentucky'),
#  ('Chandler, Tyson', 'Manuel Dominguez HS (CA)'),
#  ('Chriss, Marquese', 'Washington'),
#  ('Dudley, Jared', 'Boston College'),
#  ('Jackson, Josh', 'Kansas'),
#  ('James, Mike', 'Lamar'),
#  ('Jones, Derrick', 'UNLV'),
#  ('Knight, Brandon', 'Kentucky'),
#  ('Len, Alex', 'Maryland'),
#  ('Millsap, Elijah', u'Alabama\u2013Birmingham'),
#  ('Peters, Alec', 'Valparaiso'),
#  ('Reed, Davon', 'Miami (FL)'),
#  ('Ulis, Tyler', 'Kentucky'),
#  ('Warren, T. J.', 'North Carolina State'),
#  ('Williams, Alan', 'UC Santa Barbara'),
#  (u'Bogdanovi\u0107, Bogdan', 'Serbia'),
#  ('Carter, Vince', 'North Carolina'),
#  ('Cauley-Stein, Willie', 'Kentucky'),
#  ('Cooley, Jack', 'Notre Dame'),
#  ("Fox, De'Aaron", 'Kentucky'),
#  ('Giles, Harry', 'Duke'),
#  ('Hield, Buddy', 'Oklahoma'),
#  ('Hill, George', 'IUPUI'),
#  ('Jackson, Justin', 'North Carolina'),
#  ('Koufos, Kosta', 'Ohio State'),
#  (u'Labissi\xe8re, Skal', 'Kentucky'),
#  ('Mason III, Frank', 'Kansas'),
#  ('Papagiannis, Georgios', 'American School (GRE)'),
#  ('Randolph, Zach', 'Michigan State'),
#  ('Richardson, Malachi', 'Syracuse'),
#  ('Sampson, JaKarr', "St. John's"),
#  ('Temple, Garrett', 'LSU')]

# %%
df = pd.DataFrame(finaldata)
df.head()
# Out:
#                  0                 1
# 0    Allen, Kadeem           Arizona
# 1     Baynes, Aron  Washington State
# 2     Bird, Jabari       UC Berkeley
# 3    Brown, Jaylen       UC Berkeley
# 4  Hayward, Gordon            Butler

# %%
df=df.rename(columns={0: 'Players', 1: 'Schools'})
df.head()
# Out:
#            Players           Schools
# 0    Allen, Kadeem           Arizona
# 1     Baynes, Aron  Washington State
# 2     Bird, Jabari       UC Berkeley
# 3    Brown, Jaylen       UC Berkeley
# 4  Hayward, Gordon            Butler

# %%
# most successful schools
df.groupby('Schools').count()
# Out:
#                                   Players
# Schools
# Advanced Prep International (TX)        1
# Alabama                                 1
# Alabama–Birmingham                      1
# American School (GRE)                   1
# Argentina                               2
# Arizona                                13
# Arizona State                           1
# Arkansas                                3
# Baylor                                  5
# Belmont                                 1
# Bosnia and Herzegovina                  2
# Boston College                          2
# Bowling Green                           1
# Brazil                                  4
# Bucknell                                1
# Butler                                  2
# CCSE Prep (CA)                          1
# Cal Poly San Luis Obispo                1
# Campbell                                1
# Cape Verde                              1
# Central Florida                         1
# China                                   1
# Cincinnati                              2
# Clemson                                 3
# Colorado                                4
# Colorado State                          2
# Connecticut                             6
# Creighton                               4
# Croatia                                 6
# Czech Republic                          1
# ...                                   ...
# Tennessee State                         1
# Texas                                  10
# Texas A&M                               4
# Texas–El Paso                           1
# Tunisia                                 1
# Turkey                                  4
# UC Berkeley                             5
# UC Santa Barbara                        1
# UCLA                                   14
# UNLV                                    5
# USC Upstate                             1
# Utah                                    3
# Utah State                              1
# Valparaiso                              1
# Vanderbilt                              3
# Villanova                               5
# Virginia                                5
# Virginia Commonwealth                   3
# Virginia Tech                           1
# Wake Forest                             6
# Washington                              9
# Washington State                        2
# Weber State                             3
# Westchester CC                          1
# Westchester HS (CA)                     1
# Western Kentucky                        1
# Wichita State                           2
# Wisconsin                               6
# Wyoming                                 1
# Xavier                                  4
#
# [163 rows x 1 columns]

# %%
pop = df.groupby('Schools').count()
pop.sort_values('Players', ascending=False)
# Out:
#                                    Players
# Schools
# Kentucky                                27
# Duke                                    20
# North Carolina                          17
# Kansas                                  16
# UCLA                                    14
# Arizona                                 13
# Texas                                   10
# Florida                                  9
# Syracuse                                 9
# Washington                               9
# Indiana                                  9
# Michigan State                           8
# France                                   8
# Spain                                    7
# Serbia                                   7
# Marquette                                7
# LSU                                      7
# Michigan                                 7
# Germany                                  6
# Stanford                                 6
# Croatia                                  6
# Connecticut                              6
# Louisville                               6
# Wisconsin                                6
# Wake Forest                              6
# Florida State                            5
# Notre Dame                               5
# Gonzaga                                  5
# Baylor                                   5
# Virginia                                 5
# ...                                    ...
# New Mexico                               1
# Lausanne CS (TN)                         1
# Murray State                             1
# Morehead State                           1
# Alabama                                  1
# Lehigh                                   1
# Long Beach State                         1
# Louisiana Tech                           1
# Marshall                                 1
# IUPUI                                    1
# Penn State                               1
# Peoria Central HS (IL)                   1
# Green Bay                                1
# Slovenia                                 1
# Loyola (IL)                              1
# Seton Hall                               1
# Ghana                                    1
# San Diego State                          1
# Greece                                   1
# Saint Louis                              1
# Saint Benedict's Preparatory (NJ)        1
# Holy Cross                               1
# Russia                                   1
# Republic of the Congo                    1
# Harvard                                  1
# Providence                               1
# Prime Prep Academy (TX)                  1
# Prentiss HS (MS)                         1
# Poland                                   1
# Advanced Prep International (TX)         1
#
# [163 rows x 1 columns]

# %% [markdown]
# # Example 6
#
# - http://www.basketball-reference.com/draft/
# - http://www.basketball-reference.com/draft/BAA_1947.html

# %%
r = requests.get('http://www.basketball-reference.com/draft/BAA_1947.html')
data = html.fromstring(r.text)

# %%
player = data.xpath("//td[@data-stat='player']/@csk")
player
# Out:
# ['McNeeley,Clifton',
#  'Selbo,Glen',
#  'Ehlers,Bulbs',
#  'Dropo,Walt',
#  'Holub,Dick',
#  'Crossin,Chink',
#  'Underman,Jack',
#  'Huston,Paul',
#  "O'Keefe,Dick",
#  'Killick,Larry',
#  'Bolyard,Robert',
#  'Gainer,Elmer',
#  'Gallatin,Harry',
#  'Hamilton,Scotty',
#  'Hampton,Hugh',
#  'Jake,Bob',
#  'Raynor,Charles',
#  'Reiser,Chick',
#  'Rusinko,John',
#  'Alemeida,Bob',
#  'Biasatti,Hank',
#  'Ezersky,Johnny',
#  'Felt,George',
#  'Hewson,Jack',
#  'Kelly,John',
#  'Petrovick,George',
#  'Stump,Gene',
#  'Bishop,Ralph',
#  'Darden,Jimmy',
#  'Decker,Hank',
#  'Phillip,Andy',
#  'Pollard,Jim',
#  'Schadler,Ben',
#  'Smith,Don',
#  'Stone,Jack',
#  'Vance,Gene',
#  'Duncan,Andy',
#  'Evans,Ray',
#  'Golub,Ed',
#  'Head,Garland',
#  'Livingston,Ron',
#  'Miller,Dan',
#  'Misaka,Wat',
#  'Reichert,Carl',
#  'Tomlinson,Tom',
#  'Butz,Norman',
#  'Kaeding,Jim',
#  'Koffenberger,Ed',
#  'Pollard,Jim',
#  'Alamo,Bob',
#  'Brown,George',
#  'Ives,Dick',
#  'Knoche,Herman',
#  'Nagy,Fritz',
#  'Walton,Jack',
#  'Barry,Joe',
#  'Furey,Dick',
#  'Hubbard,Bob',
#  'Joyce,Bob',
#  'Lipscomb,Roy',
#  'Mills,John',
#  'Nichols,Al',
#  'Knopf,Jack',
#  'Kurland,Bob',
#  'Napolitano,Paul',
#  'Pollard,Jim',
#  'Strannigan,Bill',
#  'Wilkinson,Herb',
#  'Broyles,Frank',
#  'Hoffman,Paul',
#  'Quinn,Wimpy',
#  'Rocha,Red',
#  'Burke,Bill',
#  'Cloyd,Paul',
#  'Mandic,John',
#  'Mariaschin,Saul',
#  'Rodriguez,Abel',
#  'Rothenberg,Irv',
#  'Tingle,Jack',
#  'Zunic,Matt']

# %%
pts_per_g = data.xpath("//td[@data-stat='pts_per_g']/text()")
pts_per_g
# Out:
# ['3.2',
#  '8.1',
#  '10.5',
#  '4.7',
#  '3.6',
#  '5.2',
#  '1.5',
#  '13.0',
#  '10.4',
#  '1.0',
#  '7.6',
#  '2.7',
#  '5.3',
#  '8.1',
#  '9.1',
#  '13.2',
#  '1.5',
#  '0.8',
#  '8.3',
#  '5.5',
#  '2.3',
#  '13.2',
#  '5.1',
#  '3.6',
#  '0.0',
#  '13.2',
#  '10.2',
#  '10.9',
#  '2.7',
#  '4.1',
#  '7.7',
#  '5.4',
#  '2.3',
#  '4.9']

# %%
print len(player), len(pts_per_g)
# Out:
# 80 34

# %% [markdown]
# Note: 80 players, but points-per-game are available for 34 players. Thus, combining these two columns is NOT working.

# %%
finaldata = zip(player, pts_per_g)
finaldata
# Out:
# [('McNeeley,Clifton', '3.2'),
#  ('Selbo,Glen', '8.1'),
#  ('Ehlers,Bulbs', '10.5'),
#  ('Dropo,Walt', '4.7'),
#  ('Holub,Dick', '3.6'),
#  ('Crossin,Chink', '5.2'),
#  ('Underman,Jack', '1.5'),
#  ('Huston,Paul', '13.0'),
#  ("O'Keefe,Dick", '10.4'),
#  ('Killick,Larry', '1.0'),
#  ('Bolyard,Robert', '7.6'),
#  ('Gainer,Elmer', '2.7'),
#  ('Gallatin,Harry', '5.3'),
#  ('Hamilton,Scotty', '8.1'),
#  ('Hampton,Hugh', '9.1'),
#  ('Jake,Bob', '13.2'),
#  ('Raynor,Charles', '1.5'),
#  ('Reiser,Chick', '0.8'),
#  ('Rusinko,John', '8.3'),
#  ('Alemeida,Bob', '5.5'),
#  ('Biasatti,Hank', '2.3'),
#  ('Ezersky,Johnny', '13.2'),
#  ('Felt,George', '5.1'),
#  ('Hewson,Jack', '3.6'),
#  ('Kelly,John', '0.0'),
#  ('Petrovick,George', '13.2'),
#  ('Stump,Gene', '10.2'),
#  ('Bishop,Ralph', '10.9'),
#  ('Darden,Jimmy', '2.7'),
#  ('Decker,Hank', '4.1'),
#  ('Phillip,Andy', '7.7'),
#  ('Pollard,Jim', '5.4'),
#  ('Schadler,Ben', '2.3'),
#  ('Smith,Don', '4.9')]

# %%
pts_per_g = data.xpath("//td[@data-stat='pts_per_g']")
for i in pts_per_g:
    print i.text_content()
# Out:
# 3.2
# 8.1
#
# 10.5
# 4.7
#
# 3.6
# 5.2
#
#
# 1.5
# 13.0
#
#
#
#
# 10.4
#
#
# 1.0
# 7.6
#
# 2.7
#
#
# 5.3
#
# 8.1
#
# 9.1
# 13.2
# 1.5
# 0.8
#
# 8.3
# 5.5
#
#
#
#
#
# 2.3
#
#
#
#
#
# 13.2
#
#
#
#
# 5.1
#
#
#
# 3.6
#
#
#
#
#
#
# 0.0
# 13.2
#
#
#
# 10.2
#
# 10.9
#
# 2.7
# 4.1
# 7.7
#
# 5.4
# 2.3
# 4.9

# %%
pts_per_g = [ i.text_content() for i in pts_per_g ]
pts_per_g
# Out:
# ['',
#  '3.2',
#  '8.1',
#  '',
#  '10.5',
#  '4.7',
#  '',
#  '3.6',
#  '5.2',
#  '',
#  '',
#  '1.5',
#  '13.0',
#  '',
#  '',
#  '',
#  '',
#  '10.4',
#  '',
#  '',
#  '1.0',
#  '7.6',
#  '',
#  '2.7',
#  '',
#  '',
#  '5.3',
#  '',
#  '8.1',
#  '',
#  '9.1',
#  '13.2',
#  '1.5',
#  '0.8',
#  '',
#  '8.3',
#  '5.5',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2.3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '13.2',
#  '',
#  '',
#  '',
#  '',
#  '5.1',
#  '',
#  '',
#  '',
#  '3.6',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '0.0',
#  '13.2',
#  '',
#  '',
#  '',
#  '10.2',
#  '',
#  '10.9',
#  '',
#  '2.7',
#  '4.1',
#  '7.7',
#  '',
#  '5.4',
#  '2.3',
#  '4.9']

# %%
finaldata = zip(player, pts_per_g)
finaldata
# Out:
# [('McNeeley,Clifton', ''),
#  ('Selbo,Glen', '3.2'),
#  ('Ehlers,Bulbs', '8.1'),
#  ('Dropo,Walt', ''),
#  ('Holub,Dick', '10.5'),
#  ('Crossin,Chink', '4.7'),
#  ('Underman,Jack', ''),
#  ('Huston,Paul', '3.6'),
#  ("O'Keefe,Dick", '5.2'),
#  ('Killick,Larry', ''),
#  ('Bolyard,Robert', ''),
#  ('Gainer,Elmer', '1.5'),
#  ('Gallatin,Harry', '13.0'),
#  ('Hamilton,Scotty', ''),
#  ('Hampton,Hugh', ''),
#  ('Jake,Bob', ''),
#  ('Raynor,Charles', ''),
#  ('Reiser,Chick', '10.4'),
#  ('Rusinko,John', ''),
#  ('Alemeida,Bob', ''),
#  ('Biasatti,Hank', '1.0'),
#  ('Ezersky,Johnny', '7.6'),
#  ('Felt,George', ''),
#  ('Hewson,Jack', '2.7'),
#  ('Kelly,John', ''),
#  ('Petrovick,George', ''),
#  ('Stump,Gene', '5.3'),
#  ('Bishop,Ralph', ''),
#  ('Darden,Jimmy', '8.1'),
#  ('Decker,Hank', ''),
#  ('Phillip,Andy', '9.1'),
#  ('Pollard,Jim', '13.2'),
#  ('Schadler,Ben', '1.5'),
#  ('Smith,Don', '0.8'),
#  ('Stone,Jack', ''),
#  ('Vance,Gene', '8.3'),
#  ('Duncan,Andy', '5.5'),
#  ('Evans,Ray', ''),
#  ('Golub,Ed', ''),
#  ('Head,Garland', ''),
#  ('Livingston,Ron', ''),
#  ('Miller,Dan', ''),
#  ('Misaka,Wat', '2.3'),
#  ('Reichert,Carl', ''),
#  ('Tomlinson,Tom', ''),
#  ('Butz,Norman', ''),
#  ('Kaeding,Jim', ''),
#  ('Koffenberger,Ed', ''),
#  ('Pollard,Jim', '13.2'),
#  ('Alamo,Bob', ''),
#  ('Brown,George', ''),
#  ('Ives,Dick', ''),
#  ('Knoche,Herman', ''),
#  ('Nagy,Fritz', '5.1'),
#  ('Walton,Jack', ''),
#  ('Barry,Joe', ''),
#  ('Furey,Dick', ''),
#  ('Hubbard,Bob', '3.6'),
#  ('Joyce,Bob', ''),
#  ('Lipscomb,Roy', ''),
#  ('Mills,John', ''),
#  ('Nichols,Al', ''),
#  ('Knopf,Jack', ''),
#  ('Kurland,Bob', ''),
#  ('Napolitano,Paul', '0.0'),
#  ('Pollard,Jim', '13.2'),
#  ('Strannigan,Bill', ''),
#  ('Wilkinson,Herb', ''),
#  ('Broyles,Frank', ''),
#  ('Hoffman,Paul', '10.2'),
#  ('Quinn,Wimpy', ''),
#  ('Rocha,Red', '10.9'),
#  ('Burke,Bill', ''),
#  ('Cloyd,Paul', '2.7'),
#  ('Mandic,John', '4.1'),
#  ('Mariaschin,Saul', '7.7'),
#  ('Rodriguez,Abel', ''),
#  ('Rothenberg,Irv', '5.4'),
#  ('Tingle,Jack', '2.3'),
#  ('Zunic,Matt', '4.9')]

# %%
df = pd.DataFrame(finaldata)
df
# Out:
#                    0     1
# 0   McNeeley,Clifton
# 1         Selbo,Glen   3.2
# 2       Ehlers,Bulbs   8.1
# 3         Dropo,Walt
# 4         Holub,Dick  10.5
# 5      Crossin,Chink   4.7
# 6      Underman,Jack
# 7        Huston,Paul   3.6
# 8       O'Keefe,Dick   5.2
# 9      Killick,Larry
# 10    Bolyard,Robert
# 11      Gainer,Elmer   1.5
# 12    Gallatin,Harry  13.0
# 13   Hamilton,Scotty
# 14      Hampton,Hugh
# 15          Jake,Bob
# 16    Raynor,Charles
# 17      Reiser,Chick  10.4
# 18      Rusinko,John
# 19      Alemeida,Bob
# 20     Biasatti,Hank   1.0
# 21    Ezersky,Johnny   7.6
# 22       Felt,George
# 23       Hewson,Jack   2.7
# 24        Kelly,John
# 25  Petrovick,George
# 26        Stump,Gene   5.3
# 27      Bishop,Ralph
# 28      Darden,Jimmy   8.1
# 29       Decker,Hank
# ..               ...   ...
# 50      Brown,George
# 51         Ives,Dick
# 52     Knoche,Herman
# 53        Nagy,Fritz   5.1
# 54       Walton,Jack
# 55         Barry,Joe
# 56        Furey,Dick
# 57       Hubbard,Bob   3.6
# 58         Joyce,Bob
# 59      Lipscomb,Roy
# 60        Mills,John
# 61        Nichols,Al
# 62        Knopf,Jack
# 63       Kurland,Bob
# 64   Napolitano,Paul   0.0
# 65       Pollard,Jim  13.2
# 66   Strannigan,Bill
# 67    Wilkinson,Herb
# 68     Broyles,Frank
# 69      Hoffman,Paul  10.2
# 70       Quinn,Wimpy
# 71         Rocha,Red  10.9
# 72        Burke,Bill
# 73        Cloyd,Paul   2.7
# 74       Mandic,John   4.1
# 75   Mariaschin,Saul   7.7
# 76    Rodriguez,Abel
# 77    Rothenberg,Irv   5.4
# 78       Tingle,Jack   2.3
# 79        Zunic,Matt   4.9
#
# [80 rows x 2 columns]

# %% [markdown]
# # Recommended Reading (& Resources)
#
# - http://docs.python-guide.org/en/latest/scenarios/scrape/
# - http://lxml.de/xpathxslt.html
# - http://www.w3schools.com/xml/xpath_intro.asp
# - http://infohost.nmt.edu/tcc/help/pubs/pylxml/web/index.html

# %% [markdown]
# # Appendix: Web Crawling (Collecting data from multiple webpages) - MIS670

# %% [markdown]
# ### Example: http://sfbay.craigslist.org/search/npo?s=

# %%
a = "http://sfbay.craigslist.org/search/npo?s="
count = 0
for i in range(1,5):
    print '%s%s' %(a,count)
    count = count + 100
# Out:
# http://sfbay.craigslist.org/search/npo?s=0
# http://sfbay.craigslist.org/search/npo?s=100
# http://sfbay.craigslist.org/search/npo?s=200
# http://sfbay.craigslist.org/search/npo?s=300

# %%
a = "http://sfbay.craigslist.org/search/npo?s="
count = 0
for i in range(1,3):
    webpage = '%s%s' %(a,count)
    count = count + 100      
    r = requests.get(webpage)
    data = html.fromstring(r.text)
    
    # xpath: collect the specific data you're looking for
    title = data.xpath("//p[@class='result-info']/a/text()")
    url = data.xpath("//p[@class='result-info']/a/@href")
    
    print title, url
# Out:
# ['JOB DEVELOPER', 'Defend Immigrant Rights on behalf of the ACLU! Earn $13-$17/hour', 'Executive Director', 'COMMUNITY WORK SUPERVISOR - PART TIME', 'Clinical Training and Quality Assurance (QA) Director', 'Supportive Living Attendant - South Bay Area', 'Case Manager III- SF Outpatient', 'Work for Amnesty International- Help Protect Human Rights! (Oakland)', 'Work for Amnesty International- Help Protect Human Rights! (Oakland)', 'Work for Amnesty International-Help Protect Human Rights! (San Jose)', u'\u25b6Gain Experience making social change\u25b6 STOP TRUMP! Up to $640/wk', 'Chapter 510 | Literary Arts Nonprofit | Development & Events Manager', 'Peer Mentor - Transitions', 'Parent Partner - VTP', 'Part-Time Mock Trial Coordinator', 'Mental Health Counselor - Avalon', 'Mental Health Counselor - On-Call Avalon', 'Mental Health Therapist - Transitions', 'Clinical Social Worker Avalon', 'Maintenance/Facility Technician', 'Director of The Music School', 'Become an Activist - GET PAID TO SAVE THE TREES!', 'Part time Child and Family Therapist (30 hours/ week)', 'Marketing, Communications and Membership Manager', 'Program Manager', 'One Day At a Time (ODAT)- Community Engagement Member', 'Climate Change Communications Intern (paid)', "Farmer's Market Assistant Market Manager - On-Call", 'Wraparound Supervisor: Community-based youth program', 'Crisis Clinician - Support and stabilize youth!', "Bilingual Classroom Therapist - Children's Therapeutic Preschool", '$100 Hiring Bonus - Home Support Specialist - Flexible hours FT, PT', 'Property Acquisitions Associate', 'Part-Time Driver $15/hour - Vehicle Provided', 'Director of Conservation Science (Peninsula Open Space Trust)', 'Counseling / Support Staff', 'Turn staff into leaders. Inspire campers. Be a Program Director.', 'Property Manager', 'Part or Full Time School Therapists (LCSW) - $41/ hour +', 'Education Coach', '1:1 School Aide', 'Temporary TAY Case Manager', 'Transportation Coordinator Needed!', 'Account Manager @ Conard House, Inc.', 'OAKLAND PARKS FOUNDATION --- Program and Operations Assistant', 'Development Specialist (2017-116)', 'Program Manager: First 5 (2017-115)', 'FELLOWSHIP with Executive Director', 'School based Clinicians - Immediate Hire', 'Care Coordinator for Residential Treatment Facility - Variable Hour', 'Team Lead for our School based program - 2 Openings for immediate Hire', 'Development/Administraive Assistant', 'Clinical Counselor', 'WANTED NOW: Experienced Fundraiser/Community Organizer ($14-$16/HR)', 'Youth Housing Counselor (1480)', 'Master Level Clinicians - Work with Underserved Communities', 'Housing Case Manager - Mental Health', 'Temporary Case Managers', 'CASE MANAGER: Senior Service Coordinator North Bay Regional Center', 'Bilingual Optometry Assistant needed! Join the La Clinica family!', 'Program Supervisor II', 'Mental Health Care Manager - Relief/On Call', 'Mental Health: Full-time Care Manager, evening/weekend shifts', 'Case Manager, San Mateo County', 'Entry Level Recruiter For Fundraising Organization', u'\u2605HIRING IMMEDIATELY - PAID CAMPAIGN JOBS: FIGHT FOR EQUALITY!', 'Social Work Case Management $16.95/hour -Tri-Valley', '9:00P-7:00A Sat-Mon Residential Counselor', 'Relief Residential Counselor', 'Family Engagement Coordinator', 'Work for Amnesty International-Help Protect Human Rights! (San Jose)', 'Mental Health Case Manager - Turning Point', 'Work for Amnesty International- Help Protect Human Rights! (Oakland)', 'Social Worker - Immigration Practice', 'Youth Activities Coordinator/Part Time', 'Mental Health Counselor - On-Call New Yosemite', 'Mental Health Counselor - New Yosemite', 'Bi-Lingual Mental Health Therapist - San Mateo', 'TBS Worker San Mateo - Bi-Lingual Preferred', 'Mental Health Therapist - San Mateo', 'Peer Specialist *Multiple Opportunities* Job#HW06071701', 'Family Partnerships Coordinator', 'promote PEACE and DIPLOMACY', 'Garbage Truck Driver', 'Director of Social Services/ Youth Leader', 'Stage Manager--Vall ...
# ['Assistant Director - Progress Foundation La Posada', 'Program Director - Seniors- Progress Foundation', 'Assistant Director -- Shrader House', 'Assistant Director- Progress Sonoma', 'Housing Navigator -Multiple Positions Available #:HW04281701', 'Intensive Care Coordinator', 'Project Manager, CA Food is Medicine Pilot Project', 'Property Supervisor', 'Maintenance II - Great Benefits!', 'Make a Difference - Join the ESBA Team! -  Paid Training - ABA Therapy', 'Admissions Counselor', 'Hiring Immediately for Outreach Staff -- --  Speak for the Trees!', 'Licensed Vocational Nurse - FTE w/Benefits (New Crisis Residential)', 'Clinician I - New Crisis Residential', 'Licensed Psychiatric Technician - IOP-120 Outpatient (FTE w/Benefits)', 'Training Coordinator', u'\u25baGIRLS ROCK\u25c4 Women Warriors Needed to Help Fight HIV  $$', u'\u25baGIRLS ROCK\u25c4 Women Warriors Needed to Help Fight HIV  $$', 'Crisis Residential Specialist - New Crisis Residential', u'\u25baGIRLS ROCK\u25c4 Women Warriors Needed to Help Fight HIV  $$', 'Clinician I/II - Licensure Preferred -Alameda OP', 'Development/Administraive Assistant', 'COMMUNITY SERVICES SPECIALIST - FARSI/ENGLISH SPEAKING REQUIRED', 'Community Services Specialist - Eastside OP', 'Facilities Technician-Crisis Stabilization/New Crisis Res Units', 'Bilingual Child Care Provider Support Specialist', 'Program Director', 'Assistant Manager - Supportive Housing  (La Selva Group)', 'Executive Assistant  to Inspiring Team in Tech Driven Nonprofit', 'Cook - Serenity House - San Mateo', 'HR/Talent Manager', 'Community Based Organization Mental Health  Recovery Program', 'Counselor - Substance Abuse Program', 'Planned Giving Marketing and Donor Management Assistant', 'Project Manager (Temporary)', 'Relocation Specialist (Temporary)', 'Assistant Manager (Broadway Sansome)', 'Property Manager', 'Intensive Case Manager (RAD)', 'School-based Therapist - temp to perm', 'Community Organizer (Housing Counseling and Small Sites)', 'Youth Services Coordinator (Tenderloin Family Housing)', 'Family Liaison', 'Preschool Teacher - Bilingual-Engl/Span (East Palo Alto, CA)', 'Assistant Director, Facility Rental Program', 'Clinic Supervisor at our School Based Health Center (Roosevelt) Needed', 'Development Associate', 'After-School Program- Love Cultivating Schoolyard Instructor (17-18)', 'After-School Program Instructor -Bret Harte Middle School (2017-2018)', 'RAPIDLY EXPANDING: HIRING (5) LIFE SKILLS COACHES IMMEDIATE (PT to FT)', 'Director of Pro Bono Legal Services', 'LINKAGES CASE MANAGER', 'Afterschool teachers/Rec leader', 'Peer Support Worker, (AOT / San Mateo)', 'Bilingual (Spanish/English) Drop-In Childcare Provider - Compass', u'\u272aMAKE AN IMPACT ON AN HISTORIC CIVIL RIGHTS CAMPAIGN $13-$17/hour', 'Digital Marketing Manager (Peninsula Open Space Trust)', 'Start Your Fundraising Career Today! $17-$20/hour, Benefits, Travel', 'Donor Stewardship & Events Coordinator (Peninsula Open Space Trust)', "Receptionist - Compass Children's Center", 'Certified Nursing Assistant-SNF (PM Shift)', 'Work for Amnesty International- Help Protect Human Rights! (Oakland)', 'MENTAL HEALTH COUNSELOR/ADMISSIONS COORDINATOR/GROUP FACILITIATOR', 'ON-CALL MENTAL HEALTH COUNSELOR FOR 24-HR RESIDENTIAL PROGRAM', 'Certified Nursing Assistant-SNF (AM Shift)', 'Slide Ranch seeks Program Director', 'Housing Coordinator', 'Work for Amnesty International-Help Protect Human Rights! (San Jose)', 'Program Manager', 'Mental Health Counselor - Avalon', 'Mental Health Counselor - On-Call Avalon', 'Mental Health Therapist - Transitions', 'Clinical Social Worker Avalon', 'Bi-Lingual Mental Health Clinician - Visiting Therapist Program', 'Labor Relations Manager, Northern California', 'Mental Health Therapist - Visiting Therapist Program', 'Mental Health Therapist - AC TBS / In-Home', 'Bi-Lingual Mental Health Therapist - San Mateo', 'MORE BENEFITS for Life Coaches!  [Health Insurance, Bonuses, Mileage ]', 'Now Hiring!  Tuesdays, Thursdays ...

# %%
# creating an empty list (or data storage)
finaldata = []

a = "http://sfbay.craigslist.org/search/npo?s="
count = 0
for i in range(1,3):
    webpage = '%s%s' %(a,count)
    count = count + 100      
    r = requests.get(webpage)
    data = html.fromstring(r.text)
    
    # xpath: collect the specific data you're looking for
    title = data.xpath("//p[@class='result-info']/a/text()")
    url = data.xpath("//p[@class='result-info']/a/@href")
    
    crawleddata = zip(title, url)
    
    for row in crawleddata:
        finaldata.append(row)    

finaldata = pd.DataFrame(finaldata)       
finaldata.to_csv("data/output_craiglist.csv", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-71-9111904af115> in <module>()
#      20
#      21 finaldata = pd.DataFrame(finaldata)
# ---> 22 finaldata.to_csv("data/output_craiglist.csv", encoding="utf-8")
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1411                                      doublequote=doublequote,
#    1412                                      escapechar=escapechar, decimal=decimal)
# -> 1413         formatter.save()
#    1414
#    1415         if path_or_buf is None:
#
# /anaconda/lib/python2.7/site-packages/pandas/io/formats/format.pyc in save(self)
#    1566             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1567                                      encoding=self.encoding,
# -> 1568                                      compression=self.compression)
#    1569             close = True
#    1570
#
# /anaconda/lib/python2.7/site-packages/pandas/io/common.pyc in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     374         if compat.PY2:
#     375             # Python 2
# --> 376             f = open(path_or_buf, mode)
#     377         elif encoding:
#     378             # Python 3 and encoding
#
# IOError: [Errno 2] No such file or directory: 'data/output_craiglist.csv'

# %% [markdown]
# ### Example: http://econpy.pythonanywhere.com/ex/001

# %%
# creating an empty list (or data storage)
finaldata = []

a = "http://econpy.pythonanywhere.com/ex/00"
count = 1
b = ".html"
for i in range(1,5):
    webpage = '%s%s%s' %(a,count,b)
    count = count + 1      
    r = requests.get(webpage)
    data = html.fromstring(r.text)
    
    #create a list of buyers:
    buyers = data.xpath('//div[@title="buyer-name"]/text()')
    #create a list of prices
    prices = data.xpath('//span[@class="item-price"]/text()')

    crawleddata = zip(buyers, prices)
    
    for row in crawleddata:
        finaldata.append(row)    

finaldata = pd.DataFrame(finaldata)       
finaldata.to_csv("data/output_buyersprices.csv", encoding="utf-8")

# %% [markdown]
# ### Example: http://www.basketball-reference.com/draft/BAA_1947.html

# %%
# creating an empty list (or data storage)
finaldata = []

a = "http://www.basketball-reference.com/draft/BAA_"
count = 1947
b = ".html"
for i in range(1,5):
    webpage = '%s%s%s' %(a,count,b)
    count = count + 1      
    r = requests.get(webpage)
    data = html.fromstring(r.text)
    
    player = data.xpath("//td[@data-stat='player']/@csk")
    pts_per_g = data.xpath("//td[@data-stat='pts_per_g']")
    pts_per_g = [ i.text_content() for i in pts_per_g ]

    crawleddata = zip(player, pts_per_g)
    
    for row in crawleddata:
        finaldata.append(row)    

finaldata = pd.DataFrame(finaldata)       
finaldata.to_csv("data/output_basketball.csv", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-72-b8dca7eb8847> in <module>()
#      21
#      22 finaldata = pd.DataFrame(finaldata)
# ---> 23 finaldata.to_csv("data/output_basketball.csv", encoding="utf-8")
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1411                                      doublequote=doublequote,
#    1412                                      escapechar=escapechar, decimal=decimal)
# -> 1413         formatter.save()
#    1414
#    1415         if path_or_buf is None:
#
# /anaconda/lib/python2.7/site-packages/pandas/io/formats/format.pyc in save(self)
#    1566             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1567                                      encoding=self.encoding,
# -> 1568                                      compression=self.compression)
#    1569             close = True
#    1570
#
# /anaconda/lib/python2.7/site-packages/pandas/io/common.pyc in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     374         if compat.PY2:
#     375             # Python 2
# --> 376             f = open(path_or_buf, mode)
#     377         elif encoding:
#     378             # Python 3 and encoding
#
# IOError: [Errno 2] No such file or directory: 'data/output_basketball.csv'
